# %% [markdown]
# # Random Automatic Keyword Extraction (RAKE) - Project

# %% [markdown]
# <img src= "https://www.fleetscience.org/sites/default/files/images/customer%20ai.gif">

# %% [markdown]
# ## Summary of RAKE

# %% [markdown]
# The main purpose of the Random Automatic Keyword Extraction Algorithm is to extract meaningful keywords from the given text file. It can be implemented without the need of a corpus. The implementation of RAKE is also considered relatively easier than most of the other algorithms. Some of the drawbacks include not being able to extract meaningful words, that may not be accurate enough. It extracts key phrases from texts/individual documents.RAKE has better performance on long key phrase extraction compared to text mining algorithms.

# %% [markdown]
# ## Analytic Approach

# %% [markdown]
# The approach considered for this project is to conduct a descriptive statistics analyisis. The goal is to ensure that RAKE is implemented on the documents to extract meaningful keywords and phrases.

# %% [markdown]
# ## Data Requirements & Collection

# %% [markdown]
# The type of datasets that can be used for this particular approach can be in the form of pdf, csv files and json files. In this notebook, we will be exploring the scientific paper (datasets) with csv files as they are much more easier in extracting words. There are also pdfs that can be used to extract words, however, their results are too vague.

# %% [markdown]
# ## Coding

# %% [markdown]
# ### Import Statements

# %%
import numpy as np
import re
import string
import operator
import PyPDF2
import nltk
import pandas as pd
import re

from collections import Counter, defaultdict
from enum import Enum
from itertools import chain, groupby, product
from typing import Callable, DefaultDict, Dict, List, Optional, Set, Tuple
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
from rake_nltk import Rake

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer() 

Word = str
Sentence = str
Phrase = Tuple[str, ...]


class Metric(Enum):

    DEGREE_TO_FREQUENCY_RATIO = 0  # Uses d(w)/f(w) as the metric
    WORD_DEGREE = 1  # Uses d(w) alone as the metric
    WORD_FREQUENCY = 2  # Uses f(w) alone as the metric


class Rake:

    def __init__(
            self,
            stopwords: Optional[Set[str]] = None,
            punctuations: Optional[Set[str]] = None,
            language: str = 'english',
            ranking_metric: Metric = Metric.DEGREE_TO_FREQUENCY_RATIO,
            max_length: int = 100000,
            min_length: int = 1,
            include_repeated_phrases: bool = True,
            sentence_tokenizer: Optional[Callable[[str], List[str]]] = None,
            word_tokenizer: Optional[Callable[[str], List[str]]] = None,
    ):

        if isinstance(ranking_metric, Metric):
            self.metric = ranking_metric
        else:
            self.metric = Metric.DEGREE_TO_FREQUENCY_RATIO

        self.stopwords: Set[str]
        if stopwords:
            self.stopwords = stopwords
        else:
            self.stopwords = set(nltk.corpus.stopwords.words(language))

        
        self.punctuations: Set[str]
        if punctuations:
            self.punctuations = punctuations
        else:
            self.punctuations = set(string.punctuation)

        self.to_ignore: Set[str] = set(chain(self.stopwords, self.punctuations))

        self.min_length: int = min_length
        self.max_length: int = max_length

        self.include_repeated_phrases: bool = include_repeated_phrases

        self.sentence_tokenizer: Callable[[str], List[str]]
        if sentence_tokenizer:
            self.sentence_tokenizer = sentence_tokenizer
        else:
            self.sentence_tokenizer = nltk.tokenize.sent_tokenize
        self.word_tokenizer: Callable[[str], List[str]]
        if word_tokenizer:
            self.word_tokenizer = word_tokenizer
        else:
            self.word_tokenizer = nltk.tokenize.wordpunct_tokenize

        self.frequency_dist: Dict[Word, int]
        self.degree: Dict[Word, int]
        self.rank_list: List[Tuple[float, Sentence]]
        self.ranked_phrases: List[Sentence]
  

    def extract_keywords_from_text(self, text: str):
        sentences: List[Sentence] = self._tokenize_text_to_sentences(text)
        self.extract_keywords_from_sentences(sentences)

    def extract_keywords_from_sentences(self, sentences: List[Sentence]):
        phrase_list: List[Phrase] = self._generate_phrases(sentences)
        self._build_frequency_dist(phrase_list)
        self._build_word_co_occurrence_graph(phrase_list)
        self._build_ranklist(phrase_list)
        
    def preprocess(self, sentence: str):
        sentence=str(sentence)
        sentence=sentence.replace(r'[^\w\s]+', "") #punctuation
        sentence = sentence.lower() #Lowercase
        sentence=sentence.replace('{html}',"") #
        cleanr = re.compile('<.*?>')
        cleantext = re.sub(cleanr, '', sentence)
        rem_url=re.sub(r'http\S+', '',cleantext)
        rem_num = re.sub('[0-9]+', '', rem_url)
        tokenizer = RegexpTokenizer(r'\w+')
        tokens = tokenizer.tokenize(rem_num)  
        filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]
        stem_words=[stemmer.stem(w) for w in filtered_words]
        lemma_words=[lemmatizer.lemmatize(w) for w in stem_words]
        return " ".join(filtered_words)

    def get_ranked_phrases(text) -> List[Sentence]:
        return text.ranked_phrases

    def get_ranked_phrases_with_scores(self) -> List[Tuple[float, Sentence]]:
        return self.rank_list

    def get_word_frequency_distribution(self) -> Dict[Word, int]:
        return self.frequency_dist

    def get_word_degrees(self) -> Dict[Word, int]:
        return self.degree

    def _tokenize_text_to_sentences(self, text: str) -> List[Sentence]:
        return self.sentence_tokenizer(text)

    def _tokenize_sentence_to_words(self, sentence: Sentence) -> List[Word]:
        return self.word_tokenizer(sentence)

    def _build_frequency_dist(self, phrase_list: List[Phrase]) -> None:
        self.frequency_dist = Counter(chain.from_iterable(phrase_list))

    def _build_word_co_occurrence_graph(self, phrase_list: List[Phrase]) -> None:
        co_occurrence_graph: DefaultDict[Word, DefaultDict[Word, int]] = defaultdict(lambda: defaultdict(lambda: 0))
        for phrase in phrase_list:
            for (word, coword) in product(phrase, phrase):
                co_occurrence_graph[word][coword] += 1
        self.degree = defaultdict(lambda: 0)
        for key in co_occurrence_graph:
            self.degree[key] = sum(co_occurrence_graph[key].values())

    def _build_ranklist(self, phrase_list: List[Phrase]):
        self.rank_list = []
        for phrase in phrase_list:
            rank = 0.0
            for word in phrase:
                if self.metric == Metric.DEGREE_TO_FREQUENCY_RATIO:
                    rank += 1.0 * self.degree[word] / self.frequency_dist[word]
                elif self.metric == Metric.WORD_DEGREE:
                    rank += 1.0 * self.degree[word]
                else:
                    rank += 1.0 * self.frequency_dist[word]
            self.rank_list.append((rank, ' '.join(phrase)))
        self.rank_list.sort(reverse=True)
        self.ranked_phrases = [ph[1] for ph in self.rank_list]

    def _generate_phrases(self, sentences: List[Sentence]) -> List[Phrase]:
        phrase_list: List[Phrase] = []
        for sentence in sentences:
            word_list: List[Word] = [word.lower() for word in self._tokenize_sentence_to_words(sentence)]
            phrase_list.extend(self._get_phrase_list_from_words(word_list))

        if not self.include_repeated_phrases:
            unique_phrase_tracker: Set[Phrase] = set()
            non_repeated_phrase_list: List[Phrase] = []
            for phrase in phrase_list:
                if phrase not in unique_phrase_tracker:
                    unique_phrase_tracker.add(phrase)
                    non_repeated_phrase_list.append(phrase)
            return non_repeated_phrase_list

        return phrase_list

    def _get_phrase_list_from_words(self, word_list: List[Word]) -> List[Phrase]:
        groups = groupby(word_list, lambda x: x not in self.to_ignore)
        phrases: List[Phrase] = [tuple(group[1]) for group in groups if group[0]]
        return list(filter(lambda x: self.min_length <= len(x) <= self.max_length, phrases))

# %%
r = Rake()

# %%
pdf_file = open('Entropy.pdf', 'rb')
read_pdf = PyPDF2.PdfFileReader(pdf_file)
num_pages = read_pdf.getNumPages()
for x in range(num_pages):
    pageObj = read_pdf.getPage(x)
    page = pageObj.extractText()
    text = str(page)
    print(text)

# %%
r.preprocess(text)
r.extract_keywords_from_text(text)
r.get_ranked_phrases()
# Out:
# ['digging language model — maximum entropy phrase extraction',
#  'halyomorpha halys using molecular gut content analysis',
#  '30 august – 3 september 2010',
#  '11 – 14 august 1999',
#  '12 – 16 september 2016',
#  'keyword extraction using word co',
#  '1 – 5 september 2008',
#  '4 – 6 december 2010',
#  '25 – 29 october 2014',
#  '25 – 26 july 2004',
#  'neural probabilistic language model',
#  'practical automatic keyphrase extraction',
#  'rapid automatic keyword extraction',
#  'information extraction algorithm based',
#  'open access article distributed',
#  'keyword extraction based',
#  'planning using triz',
#  'hidden markov model',
#  '1 – 4',
#  'natural language processin',
#  'natural language processing',
#  '917 – 921',
#  '564 – 577',
#  '54 – 58',
#  '54 – 58',
#  '51 – 68',
#  '491 – 509',
#  '46 – 53',
#  '4348 – 4360',
#  '404 – 411',
#  '254 – 255',
#  '1532 – 1543',
#  '1216 – 1247',
#  '1137 – 1155',
#  'based hmm approach',
#  'http :// creativecommons',
#  'emnlp ), doha',
#  'creative commons attribution',
#  'chinese news document',
#  '6 march 2012',
#  'q .; zhang',
#  'expert systems applications',
#  'analyzing technology innovation',
#  '38 – 49',
#  'identifying technology trends',
#  'patent 8131735 b2',
#  'r .; vincent',
#  'r .; tarau',
#  'r .; slakhorst',
#  'r .; probert',
#  'p .; jauvin',
#  'e .; gutwin',
#  'b .; phaal',
#  'c .; nevill',
#  'c .; brussee',
#  'c .; brussee',
#  'text mining techniques',
#  'applying text mining',
#  'expert systems application',
#  'h .; jo',
#  'j .; socher',
#  'j .; fan',
#  'r .; manning',
#  'c .; li',
#  'h .- j',
#  'word representation',
#  'keyword selection',
#  '2014 conference',
#  '2004 conference',
#  '.; ducharme',
#  'patent analysis',
#  'patent analysis',
#  'morphology analysis',
#  'text mining',
#  'text mining',
#  'technology roadmapping',
#  'information science',
#  'information retrieval',
#  'expert syst',
#  '.; lee',
#  '.; lee',
#  'processing strategy',
#  'identifying predators',
#  '© 2018',
#  'wuhan univ',
#  'topic detection',
#  'licensee mdpi',
#  'international workshop',
#  'international conference',
#  'international conference',
#  'global vectors',
#  'energy sector',
#  'empirical methods',
#  'empirical methods',
#  'digital libraries',
#  'czech republic',
#  'clustering keywords',
#  'bringing order',
#  'acm conference',
#  '2010',
#  '19 24',
#  '104 19',
#  '0 /).',
#  '25',
#  '30',
#  '3',
#  '4',
#  '29',
#  '26',
#  '2008',
#  '12',
#  'analysis',
#  'article',
#  'text',
#  'r',
#  'r',
#  'r',
#  'r',
#  'patent',
#  'p',
#  'manning',
#  'li',
#  'e',
#  'b',
#  'application',
#  '2012',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'h',
#  'h',
#  'h',
#  'lee',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  '38',
#  '38',
#  'zhou',
#  'yoon',
#  'yoon',
#  'workshops',
#  'witten',
#  'wartena',
#  'wartena',
#  'wang',
#  'w',
#  'w',
#  'w',
#  'v',
#  'usa',
#  'u',
#  'turin',
#  'tseng',
#  'tf',
#  'texts',
#  'textrank',
#  'terms',
#  'switzerland',
#  'speech',
#  'spain',
#  'spain',
#  'sci',
#  'rose',
#  'research',
#  'res',
#  'qatar',
#  'process',
#  'proceedings',
#  'proceedings',
#  'proceedings',
#  'proceedings',
#  'proceedings',
#  'proceedings',
#  'proceedings',
#  'pp',
#  'pp',
#  'pp',
#  'pp',
#  'pp',
#  'pp',
#  'pp',
#  'pennington',
#  'paynter',
#  'org',
#  'occurrence',
#  'noh',
#  'nielsen',
#  'nat',
#  'n',
#  'modeling',
#  'mihalcea',
#  'manag',
#  'manag',
#  'manag',
#  'mach',
#  'lin',
#  'lin',
#  'licenses',
#  'license',
#  'learn',
#  'l',
#  'kea',
#  'kao',
#  'kanis',
#  'k',
#  'italy',
#  'inf',
#  'inf',
#  'ind',
#  'idf',
#  'hangzhou',
#  'glove',
#  'g',
#  'g',
#  'frank',
#  'entropy2018',
#  'engineering',
#  'eng',
#  'dialogue',
#  'database',
#  'database',
#  'crow',
#  'crossref',
#  'crossref',
#  'crossref',
#  'crossref',
#  'cramer',
#  'cowley',
#  'conditions',
#  'comput',
#  'china',
#  'chang',
#  'cc',
#  'ca',
#  'brno',
#  'bilbao',
#  'berkeley',
#  'bengio',
#  'basel',
#  'barcelona',
#  'authors',
#  'appl',
#  '63',
#  '43',
#  '42',
#  '40',
#  '40',
#  '39',
#  '37',
#  '36',
#  '35',
#  '34',
#  '33',
#  '32',
#  '31',
#  '28',
#  '27',
#  '2015',
#  '2015',
#  '2007',
#  '2007',
#  '2003',
#  '20']

# %%
r.get_ranked_phrases_with_scores()
# Out:
# [(54.166666666666664,
#   'digging language model — maximum entropy phrase extraction'),
#  (42.8, 'halyomorpha halys using molecular gut content analysis'),
#  (25.515151515151512, '30 august – 3 september 2010'),
#  (24.18181818181818, '11 – 14 august 1999'),
#  (22.015151515151516, '12 – 16 september 2016'),
#  (21.666666666666668, 'keyword extraction using word co'),
#  (21.015151515151516, '1 – 5 september 2008'),
#  (19.68181818181818, '4 – 6 december 2010'),
#  (18.848484848484848, '25 – 29 october 2014'),
#  (18.848484848484848, '25 – 26 july 2004'),
#  (17.5, 'neural probabilistic language model'),
#  (16.666666666666668, 'practical automatic keyphrase extraction'),
#  (16.166666666666668, 'rapid automatic keyword extraction'),
#  (14.666666666666668, 'information extraction algorithm based'),
#  (14.5, 'open access article distributed'),
#  (11.500000000000002, 'keyword extraction based'),
#  (11.0, 'planning using triz'),
#  (11.0, 'hidden markov model'),
#  (10.681818181818182, '1 – 4'),
#  (10.5, 'natural language processin'),
#  (10.0, 'natural language processing'),
#  (9.681818181818182, '917 – 921'),
#  (9.681818181818182, '564 – 577'),
#  (9.681818181818182, '54 – 58'),
#  (9.681818181818182, '54 – 58'),
#  (9.681818181818182, '51 – 68'),
#  (9.681818181818182, '491 – 509'),
#  (9.681818181818182, '46 – 53'),
#  (9.681818181818182, '4348 – 4360'),
#  (9.681818181818182, '404 – 411'),
#  (9.681818181818182, '254 – 255'),
#  (9.681818181818182, '1532 – 1543'),
#  (9.681818181818182, '1216 – 1247'),
#  (9.681818181818182, '1137 – 1155'),
#  (9.333333333333334, 'based hmm approach'),
#  (9.0, 'http :// creativecommons'),
#  (9.0, 'emnlp ), doha'),
#  (9.0, 'creative commons attribution'),
#  (9.0, 'chinese news document'),
#  (9.0, '6 march 2012'),
#  (8.842105263157894, 'q .; zhang'),
#  (8.666666666666666, 'expert systems applications'),
#  (8.666666666666666, 'analyzing technology innovation'),
#  (8.348484848484848, '38 – 49'),
#  (8.166666666666666, 'identifying technology trends'),
#  (8.0, 'patent 8131735 b2'),
#  (7.953216374269006, 'r .; vincent'),
#  (7.953216374269006, 'r .; tarau'),
#  (7.953216374269006, 'r .; slakhorst'),
#  (7.953216374269006, 'r .; probert'),
#  (7.842105263157895, 'p .; jauvin'),
#  (7.842105263157895, 'e .; gutwin'),
#  (7.842105263157895, 'b .; phaal'),
#  (7.730994152046783, 'c .; nevill'),
#  (7.730994152046783, 'c .; brussee'),
#  (7.730994152046783, 'c .; brussee'),
#  (7.7, 'text mining techniques'),
#  (7.7, 'applying text mining'),
#  (7.666666666666666, 'expert systems application'),
#  (7.6421052631578945, 'h .; jo'),
#  (7.508771929824562, 'j .; socher'),
#  (7.508771929824562, 'j .; fan'),
#  (6.953216374269006, 'r .; manning'),
#  (6.730994152046783, 'c .; li'),
#  (6.466666666666667, 'h .- j'),
#  (5.5, 'word representation'),
#  (5.5, 'keyword selection'),
#  (5.5, '2014 conference'),
#  (5.5, '2004 conference'),
#  (4.842105263157895, '.; ducharme'),
#  (4.8, 'patent analysis'),
#  (4.8, 'patent analysis'),
#  (4.8, 'morphology analysis'),
#  (4.7, 'text mining'),
#  (4.7, 'text mining'),
#  (4.666666666666666, 'technology roadmapping'),
#  (4.666666666666666, 'information science'),
#  (4.666666666666666, 'information retrieval'),
#  (4.666666666666666, 'expert syst'),
#  (4.508771929824562, '.; lee'),
#  (4.508771929824562, '.; lee'),
#  (4.5, 'processing strategy'),
#  (4.5, 'identifying predators'),
#  (4.0, '© 2018'),
#  (4.0, 'wuhan univ'),
#  (4.0, 'topic detection'),
#  (4.0, 'licensee mdpi'),
#  (4.0, 'international workshop'),
#  (4.0, 'international conference'),
#  (4.0, 'international conference'),
#  (4.0, 'global vectors'),
#  (4.0, 'energy sector'),
#  (4.0, 'empirical methods'),
#  (4.0, 'empirical methods'),
#  (4.0, 'digital libraries'),
#  (4.0, 'czech republic'),
#  (4.0, 'clustering keywords'),
#  (4.0, 'bringing order'),
#  (4.0, 'acm conference'),
#  (4.0, '2010'),
#  (4.0, '19 24'),
#  (4.0, '104 19'),
#  (4.0, '0 /).'),
#  (3.6666666666666665, '25'),
#  (3.5, '30'),
#  (3.5, '3'),
#  (3.0, '4'),
#  (3.0, '29'),
#  (3.0, '26'),
#  (3.0, '2008'),
#  (3.0, '12'),
#  (2.8, 'analysis'),
#  (2.5, 'article'),
#  (2.2, 'text'),
#  (2.111111111111111, 'r'),
#  (2.111111111111111, 'r'),
#  (2.111111111111111, 'r'),
#  (2.111111111111111, 'r'),
#  (2.0, 'patent'),
#  (2.0, 'p'),
#  (2.0, 'manning'),
#  (2.0, 'li'),
#  (2.0, 'e'),
#  (2.0, 'b'),
#  (2.0, 'application'),
#  (2.0, '2012'),
#  (1.8888888888888888, 'c'),
#  (1.8888888888888888, 'c'),
#  (1.8888888888888888, 'c'),
#  (1.8888888888888888, 'c'),
#  (1.8888888888888888, 'c'),
#  (1.8, 'h'),
#  (1.8, 'h'),
#  (1.8, 'h'),
#  (1.6666666666666667, 'lee'),
#  (1.6666666666666667, 'j'),
#  (1.6666666666666667, 'j'),
#  (1.6666666666666667, 'j'),
#  (1.6666666666666667, 'j'),
#  (1.6666666666666667, 'j'),
#  (1.6666666666666667, 'j'),
#  (1.6666666666666667, '38'),
#  (1.6666666666666667, '38'),
#  (1.0, 'zhou'),
#  (1.0, 'yoon'),
#  (1.0, 'yoon'),
#  (1.0, 'workshops'),
#  (1.0, 'witten'),
#  (1.0, 'wartena'),
#  (1.0, 'wartena'),
#  (1.0, 'wang'),
#  (1.0, 'w'),
#  (1.0, 'w'),
#  (1.0, 'w'),
#  (1.0, 'v'),
#  (1.0, 'usa'),
#  (1.0, 'u'),
#  (1.0, 'turin'),
#  (1.0, 'tseng'),
#  (1.0, 'tf'),
#  (1.0, 'texts'),
#  (1.0, 'textrank'),
#  (1.0, 'terms'),
#  (1.0, 'switzerland'),
#  (1.0, 'speech'),
#  (1.0, 'spain'),
#  (1.0, 'spain'),
#  (1.0, 'sci'),
#  (1.0, 'rose'),
#  (1.0, 'research'),
#  (1.0, 'res'),
#  (1.0, 'qatar'),
#  (1.0, 'process'),
#  (1.0, 'proceedings'),
#  (1.0, 'proceedings'),
#  (1.0, 'proceedings'),
#  (1.0, 'proceedings'),
#  (1.0, 'proceedings'),
#  (1.0, 'proceedings'),
#  (1.0, 'proceedings'),
#  (1.0, 'pp'),
#  (1.0, 'pp'),
#  (1.0, 'pp'),
#  (1.0, 'pp'),
#  (1.0, 'pp'),
#  (1.0, 'pp'),
#  (1.0, 'pp'),
#  (1.0, 'pennington'),
#  (1.0, 'paynter'),
#  (1.0, 'org'),
#  (1.0, 'occurrence'),
#  (1.0, 'noh'),
#  (1.0, 'nielsen'),
#  (1.0, 'nat'),
#  (1.0, 'n'),
#  (1.0, 'modeling'),
#  (1.0, 'mihalcea'),
#  (1.0, 'manag'),
#  (1.0, 'manag'),
#  (1.0, 'manag'),
#  (1.0, 'mach'),
#  (1.0, 'lin'),
#  (1.0, 'lin'),
#  (1.0, 'licenses'),
#  (1.0, 'license'),
#  (1.0, 'learn'),
#  (1.0, 'l'),
#  (1.0, 'kea'),
#  (1.0, 'kao'),
#  (1.0, 'kanis'),
#  (1.0, 'k'),
#  (1.0, 'italy'),
#  (1.0, 'inf'),
#  (1.0, 'inf'),
#  (1.0, 'ind'),
#  (1.0, 'idf'),
#  (1.0, 'hangzhou'),
#  (1.0, 'glove'),
#  (1.0, 'g'),
#  (1.0, 'g'),
#  (1.0, 'frank'),
#  (1.0, 'entropy2018'),
#  (1.0, 'engineering'),
#  (1.0, 'eng'),
#  (1.0, 'dialogue'),
#  (1.0, 'database'),
#  (1.0, 'database'),
#  (1.0, 'crow'),
#  (1.0, 'crossref'),
#  (1.0, 'crossref'),
#  (1.0, 'crossref'),
#  (1.0, 'crossref'),
#  (1.0, 'cramer'),
#  (1.0, 'cowley'),
#  (1.0, 'conditions'),
#  (1.0, 'comput'),
#  (1.0, 'china'),
#  (1.0, 'chang'),
#  (1.0, 'cc'),
#  (1.0, 'ca'),
#  (1.0, 'brno'),
#  (1.0, 'bilbao'),
#  (1.0, 'berkeley'),
#  (1.0, 'bengio'),
#  (1.0, 'basel'),
#  (1.0, 'barcelona'),
#  (1.0, 'authors'),
#  (1.0, 'appl'),
#  (1.0, '63'),
#  (1.0, '43'),
#  (1.0, '42'),
#  (1.0, '40'),
#  (1.0, '40'),
#  (1.0, '39'),
#  (1.0, '37'),
#  (1.0, '36'),
#  (1.0, '35'),
#  (1.0, '34'),
#  (1.0, '33'),
#  (1.0, '32'),
#  (1.0, '31'),
#  (1.0, '28'),
#  (1.0, '27'),
#  (1.0, '2015'),
#  (1.0, '2015'),
#  (1.0, '2007'),
#  (1.0, '2007'),
#  (1.0, '2003'),
#  (1.0, '20')]

# %%
pdf_file = open('DataDriven.pdf', 'rb')
read_pdf = PyPDF2.PdfFileReader(pdf_file)
num_pages = read_pdf.getNumPages()
for x in range(num_pages):
    pageObj = read_pdf.getPage(x)
    page = pageObj.extractText()
    text = str(page)
    print(text)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Data-driven materials research enabled by naturallanguage processing and information extraction
#
#
# Cite as: Appl. Phys. Rev.7, 041317 (2020);doi: 10.1063/5.0021106Submitted: 7 July 2020.Accepted: 19 November 2020.
# Published Online: 21 December 2020
#
#
#
# Elsa A.Olivetti,1,a)
# Jacqueline M.Cole,2,3,4
# EdwardKim,5
# OlgaKononova,6,7GerbrandCeder,6,7
# Thomas Yong-JinHan,8
# and Anna M.Hiszpanski8
#
#
# AFFILIATIONS
# 1Department of Materials Science and Engineering, MIT, Cambridge, Massachusetts 02139, USA
# 2Cavendish Laboratory, Department of Physics, University of Cambridge, J. J. Thomson Avenue,Cambridge CB3 0HE, United Kingdom
# 3ISIS Neutron and Muon Source, Rutherford Appleton Laboratory, Harwell Science and Innovation Campus,Didcot OX11 0QX, United Kingdom
# 4Department of Chemical Engineering and Biotechnology, University of Cambridge, West Cambridge Site,Philippa Fawcett Drive, Cambridge CB3 0AS, United Kingdom
# 5Science, Evaluation, and Measurement, Xero, Toronto, Ontario M5H 4G1, Canada
# 6Department of Materials Science & Engineering, University of California Berkeley, Berkeley, California 94720, USA
# 7Materials Sciences Division, Lawrence Berkeley National Laboratory, Berkeley, California 94720, USA
# 8Materials Science Division, Lawrence Livermore National Laboratory, Livermore, California 94550, USA
# a)Author to whom correspondence should be addressed:elsao@mit.edu
# ABSTRACTGiven the emergence of data science and machine learning throughout all aspects of society, but particularly in the scientiﬁc domain, there isincreased importance placed on obtaining data. Data in materials science are particularly heterogeneous, based on the signiﬁcant range inmaterials classes that are explored and the variety of materials properties that are of interest. This leads to data that range many orders ofmagnitude, and these data may manifest as numerical text or image-based information, which requires quantitative interpretation. Theability to automatically consume and codify the scientiﬁc literature across domains—enabled by techniques adapted from the ﬁeld of naturallanguage processing—therefore has immense potential to unlock and generate the rich datasets necessary for data science and machinelearning. This review focuses on the progress and practices of natural language processing and text mining of materials science literature andhighlights opportunities for extracting additional information beyond text contained in ﬁgures and tables in articles. We discuss and provideexamples for several reasons for the pursuit of natural language processing for materials, including data compilation, hypothesis develop-ment, and understanding the trends within and across ﬁelds. Current and emerging natural language processing methods along with theirapplications to materials science are detailed. We, then, discuss natural language processing and data challenges within the materials sciencedomain where future directions may prove valuable.Published under license by AIP Publishing.https://doi.org/10.1063/5.0021106TABLE OF CONTENTSI. INTRODUCTION . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 2A. The scope of this review . . . . . . . . . . . . . . . . . . . . . . 3II. THE WAYS THAT NLP CAN BENEFIT DATA-DRIVEN MATERIALS SCIENCE. . . . . . . . . . . . . . . . . . . . 3III. PERFORMING NATURAL LANGUAGEPROCESSING. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 4A. Content acquisition . . . . . . . . . . . . . . . . . . . . . . . . . . 5B. Text preprocessing and tokenization . . . . . . . . . . . . 5C. Document segmentation and paragraphclassification. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 5D. Named entity recognition (NER). . . . . . . . . . . . . . . 6E. Entity relation extraction and linking . . . . . . . . . . . 7F. Conceptual network . . . . . . . . . . . . . . . . . . . . . . . . . . 8IV. RESOURCES AND TOOLS FOR NLP . . . . . . . . . . . . . . 8V. EXAMPLES OF NLP BEING USED IN MATERIALSSCIENCE . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 9VI. BEYOND BODY TEXT . . . . . . . . . . . . . . . . . . . . . . . . . . . 12
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-1Published under license by AIP Publishing
# Applied Physics ReviewsREVIEWscitation.org/journal/are
# VII. CHALLENGES AND OPPORTUNITIES. . . . . . . . . . . . 15VIII. CONCLUDING REMARKS . . . . . . . . . . . . . . . . . . . . . . 16I. INTRODUCTIONData have always been a fundamental ingredient for realizing,accelerating, and optimizing any scientiﬁc pursuit. The increasingubiquity of data science methods, based on improved computingpower and algorithm development, has driven signiﬁcant opportunityand interest in immense, structured datasets. When such data areassembled in a form readily consumed and mined using data sciencetools, coupled with domain expertise, there is tremendous potential toaccelerate discovery,
# 1build upon previous ﬁndings, rapidly enter anew ﬁeld, connect individual research efforts, and link acrossdisciplines.The physics community has long understood the value ofcurating data in a way that can be comprehended by computer logic.This is particularly true in the domains of high-energy physics, astron-omy, and astrophysics, where data emanate from very rare and spe-cialized research machines. For example, the Large Hadron Collider atCERN, in Switzerland, generates a wide range of data from particlecollisions, certain types of which can be measured using unique detec-tors, and enables collaborations among 3000 scientists and engineersfor each collaboration. Other examples include the gravitational-waveobservatories (LIGO
# 2and Virgo3collaborations are currently>1000and>500 members, respectively) and widely shared astronomicalmappings from satellites and telescopes. These sources of data tend tobe managed by large international research facilities since multi-national efforts are needed to fund and build them. Scientists workwithin large, coordinated, research consortia to produce, process, andanalyze the data.4,5Raw data are contained within each facility but areaccessible, albeit sometimes in normalized form, and their particulardata characteristics tend to limit the variety of data types.However, one aspect of the physical sciences still wanting for moreand better organized data to leverage emerging data science tools is inthe domain of materials science. Successful examples of application ofmaterials informatics to the discovery of new materials can be found inalloy development,
# 6polymer design,7organic light emitting diodes,8andsolar cells.
# 9,10However, these cases are still quite limited and suffer mostfrom lack of data. While there are a growing number of open databasesthat contain materials property information,
# 11–15most of these databasesare created from computationally calculated properties. As an example,the materials project includes computational information for over130 000 inorganic compounds, and the analogous experimental data-bases only contain 9000 materials.
# 15Experimentally based, large, andstructured materials property databases are still lacking.Unlike other ﬁelds, materials science lacks sufﬁcient incentive tomake it practical to centralize its data, not only because the data are sodiverse but also because data arise from so many independent scien-tists and laboratory sources.
# 16Figure 1illustratesthiscontrast.Datain
#
#
# FIG. 1.Comparison of large centralized datasets in high-energy physics, astronomy, and astrophysics compared to heterogeneous, decentralized data in materials physics.Unlike other ﬁelds, materials science lacks sufﬁcient incentive to make it practical to centralize the data, not only because the data are so diverse but also because the dataarise from a variety of independent scientists and laboratory sources. Data in the ﬁeld of materials science are particularly heterogeneous due to the wide variety of materialclasses studied by scientists. The data appear as numerical text or image-based information, which requires quantitative interpretation.
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-2Published under license by AIP Publishing
# materials science are particularly heterogeneous, based on the signiﬁ-cant range in materials classes that are explored and the variety ofmaterials properties that are of interest. This leads to data that rangemany orders of magnitude, and these data may manifest as numericaltext or image-based information, which requires quantitative interpre-tation. The many length scales of materials science add to this diver-sity, with data being measured from the atomic structure to massivecomponents that are integrated at a system level, such as airplanewings or turbine blades. In addition, only a small sub-set of specializedmaterials-physics research needs to be carried out at centralized facili-ties, such as government-run synchrotrons, neutron and muon sour-ces, nanocenters, high-magnetic ﬁeld laboratories, laser laboratories,or high-performance supercomputing facilities.
# 17–21Some of thesefacilities archive the raw or normalized (“reduced”) data, and someoffer their scientiﬁc users the option to tag their experimental datawith a document object identiﬁer (DOI) to make them traceable.
# 22Ifeven once such data become openly available, the metadata generatedby the experiment may be missing.
# 23Metadata are vital for processingthe data to the point where one can interpret their scientiﬁc meaning.Fortunately, there is a prospective approach to address at leastsome aspects of this data-access quandary in materials science.Scientists will cede control of their processed data if they publish theirresults, and publications continue to be the primary means of commu-nicating within the materials domain. These data will be spread acrossvarious journal articles, patents, or company reports, owing to the vari-ety of ways that scientists can publish their ﬁndings. The data will alsopresent in an unstructured form, given the highly diverse way in whichscientists write an article and select the most salient results for show-casing their scientiﬁc points (i.e., as text or in ﬁgures, tables, and sche-matics). For example, scientists may report the composition of a metalalloy in one table, the processing conditions for that alloy in the bodytext of the methods, and then the ﬁnal properties in ﬁgures within theresults. Despite the distributed nature of these processed data, harvest-ing them from documents presents a way to retrieve materials-physicsdata en masse. The manual task of mining information from docu-ments by editors is not practical, given the amount of data that areneeded to succeed in the ﬁeld of materials informatics. A means toautomatically extract materials-physics data from scientiﬁc documentsis, therefore, required. This challenge presents a prime opportunity forinformation extraction and natural language processing (NLP),whereby “materials-aware” text-mining models can be used to collateprocessed data that lie within the literature to afford auto-generatedmaterials databases that can be used in materials informatics.Capturing unstructured information from the vast and ever-growing number of scientiﬁc publications has substantial promise tomeet this need and enable creation of experimental-based databasescurrently lacking. This reliance on publications in scientiﬁc communi-cation is exempliﬁed by the proliferation of new journals and increasedfrequency of publication.
# 24–26Developing methods to mine the litera-ture for data may also prevent information loss. Without structuringinformation, scientists cannot make the necessary connections amongﬁndings; they may instead be drawn by what the authors of a scientiﬁcdocument have chosen to be highlighted in a journal or individualpublicity efforts. Scientiﬁc progress relies on hypothesis development,which requires leveraging increased knowledge toward greater under-standing, typically based on synthesizing existing information.Scientists are not trained to formalize their ﬁndings in a structuredway. The rapid growth of scientiﬁc knowledge has the potential to pro-vide opportunities to transfer solutions from one domain to addressproblems in another. However, the underlying relationships largelyremain embedded, and groups from disparate domains remain withintheir own specialties.24The signiﬁcant quantity of existing and newpublished literature. Limits what one individual can draw relationshipsbetween varied concepts, topics, and domains. There is a distinct valueto be drawn beyond what is known and what is known as individualsfrom the collective to broad multidisciplinary knowledge within andacross a given domain. This sharing and integration of informationacross communities is a tall order to accomplish comprehensively, butthe ability to automatically extract information from the literature canprovide a tool to facilitate this engagement.A. The scope of this reviewIn this review, we look at the fully and semi-automated means ofassembling and structuring scientiﬁc data through NLP and textmining. In the realm of scientiﬁc text, methods, tools, and databases ofrelevance for NLP have been most well developed for the biomedicaldomain
# 27,28where information is sought on genes, proteins, drugs,medical symptoms, and disease. These efforts exist also in the chemis-try discipline, which arguably began earlier, but tools for chemistry areless advanced than those in the biomedical domain. Efforts in chemis-try have focused on developing comprehensive chemical dictionar-ies,
# 29,30substance and small molecule composition, and structure andproperty descriptions.
# 31–34This review will focus on what has beenachieved to date in NLP for the discipline of materials science.Thestructureofthisarticleisasfollows.Weﬁrstdescribereasonsfor pursuit of NLP of scientiﬁc text given the motivation providedabove. Next, we focus on the tasks and methods involved, describingthe challenges for the materials science domain including a summaryof commonly used tools. Then, we show in detail about particularexamples of NLP applications in materials science. Next, we discussdata mining beyond NLP and how this nonetheless tracks back to thecognate need for NLP. Finally, we provide some commentary on thefuture needs and directions for the use of NLP as a tool for the materi-als community.II. THE WAYS THAT NLP CAN BENEFIT DATA-DRIVENMATERIALS SCIENCELeveraging NLP tools in materials science remains in its infancy.The methods used, and the level of accuracy required, vary dependingon the inquiring goal. Before diving into the details of how NLP is per-formed, we brieﬂy mention some of the key beneﬁts that NLP afford fordata science. These include generating datasets for mining and visualiza-tion across multiple research efforts, as well as contributing to machinelearning (ML) predictions and identifying research trends. Examples ofthe application of NLP in materials science will be provided in Sec.IV.The use of NLP on scientiﬁc text can generate libraries of infor-mation to explore, which enables data visualization, mining, and ana-lytics. The primary goals of text extraction can be used to populatedatabases with quantitative information or make text informationsummative and interactive in a way that can reveal patterns, gaps, ortrends. Advances in data analytics and visualization tools, described ingreater detail in Sec.V, have also accelerated the process of informa-tion consumption to decision-making. A well-structured databasewith an interactive and intuitive graphical user interface allows
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-3Published under license by AIP Publishing
# researchers to perform signiﬁcant background research, test hypothe-ses, survey the ﬁeld, and form a sound basis for designing andperforming experimental work, saving hours if not months of labor-intensive literature surveying and wasted experiments. Text extractioncan provide data that drive search-engine development in the scientiﬁcdomain and a beginning of active learning systems tied to automatedmaterials discovery and synthesis platforms.
# 35–37
# Beyond data extraction and visualization, researchers may alsoleverage NLP to derive fundamental insight across these data; forexample, NLP may be used to ﬁnd relationships between compoundsby mapping materials mentioned in the text to corresponding chemi-cal structures. This identiﬁcation of relationships and trends is fre-quently done by using various ML techniques on the extracted data.Scientists can search for similar chemical structures or substructures,meaning that text information can be combined with knowledge fromestablished computational-property databases. For example, this com-bination of extracted and existing data might allow for exploring andscreening the relevance of compounds to a new application as a func-tion of published properties.
# 38The ML models used vary in complex-ity, but the key opportunities for the scientiﬁc-language assemblyinclude literature-based knowledge discovery, suggesting novel scien-tiﬁc hypotheses, or predicting the outcomes of reactions.NLP activities across scientiﬁc text can also identify futureresearch trends by predicting emerging associations (co-occurrences)between selected keywords found in the scientiﬁc literature. This typeof analysis has been done previously for biochemistry,
# 39,40neurosci-ence,
# 41,42and human innovations.43,44Signiﬁcant work in this areacan also be found in the domain of “the Science of Science.”
# 24TheNLP community presents a nuanced differentiation between“information extraction” and “knowledge-based creation” (traditionaland emergent approaches, respectively). Information extraction struc-tures extracted text according to entity recognition and entity relation-ships, which, then, feed into downstream search and query-basedactivities. Knowledge-based creation can provide an end unto itself inthe form of ontology development where facts and relationships witha discipline are extracted in a form that could be used to annotatearea-speciﬁc databases or to transfer knowledge between ﬁelds. Earlyefforts in materials science have focused primarily on informationextraction. Given the need for expanded datasets in materials science(beyond what is currently available), this is a logical emphasis. As thecommunity reﬁnes key tools toward NLP for materials, a broader setof pursuits can be realized.III. PERFORMING NATURAL LANGUAGE PROCESSINGBefore delving into the speciﬁc details of methodology, we pro-vide a few key themes related to NLP, which convey the perspectivetaken in the materials science community. First, there are manualand semi-automated methods of literature-data extraction, whichyield insights into “small” datasets (i.e., tens to hundreds of relevantarticles), but the focus moving forward (and within this review) mustbe on the ability to apply methods to create large datasets (i.e., tens ofthousands of relevant articles). Generic NLP tools (such as CoreNLP)exist that do not perform well in the materials science domain with-out modiﬁcation, as the vernacular, sentence construction, terminol-ogy, and chemical semantics are specialized. Therefore, we need todevelop and apply materials-speciﬁc text mining tools to meet theneeds of this community. To reach any sort of economy of scaleacross such an interdisciplinary ﬁeld, approaches that transfer effec-tively within the materials science domain are needed, which requiresa balance between accuracy and generalizability. Each applicationspace will have local norms from which rules can be crafted for highlyaccurate information retrieval in that one domain; however, theserules often breakdown when applied to a different area of inquiry.Challenges with developing generalizable tools are also inﬂuenced bythe type of document and section within the document. Finally, thereis a tension in balancing model development toward the semantic orlinguistic structure of the document, while still incorporating criticaldomain knowledge in how individuals within the ﬁeld communicate.Natural language carries a high degree of ambiguity, and implicitknowledge plays a signiﬁcant role in how a ﬁeld communicates.However, if too much of this implicit knowledge is integrated withinmodels, leveraging the linguistic structure of the text becomes moredifﬁcult.Most natural language extraction pipelines follow a similar over-all approach, shown inFig. 2, which consists of (1) acquiring a relevantcorpus of text, (2) processing that text into individual terms, which is
#
#
# FIG. 2.Schematic of NLP including examples of tools and models at each step. It is visible that most natural language extraction follows similar approaches:(1) acquiring rele-vant text resources, (2) processing the text into individual terms (also known as tokenization), (3) document segmentation and paragraph classiﬁcation, (4) recognizing tokensas classes of information, (5) entity relation extraction, and (6) named entity linking.
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-4Published under license by AIP Publishing
# called tokenization, (3) segmenting documents and classifying para-graphs, (4) recognizing tokens as speciﬁc classes of information, gener-ally referred to as named entity recognition (NER), (5) entity relationextraction, and (6) named entity linking. Depending on the questionbeing pursued by researchers, pipelines may vary in their methods andapproach, including the order in which the above-described steps areperformed, the types of information models are provided, and devia-tions in the models themselves. Using broad strokes, we can describethe continuum of approaches as direct word mapping, deﬁning heuris-tics, and then to ML-based methods. ML approaches, in and of them-selves, can vary within the continuum of unsupervised to supervised,the latter requiring labeled data often in signiﬁcant volumes. This sec-tion describes details on each of these steps with materials-relevantmethod development presented with each step.A. Content acquisitionThe ﬁrst step is to develop and acquire a relevant corpus of sub-ject articles of interest from which information will be retrieved. Thecontent varies by the degree of accessibility, the corpus of subjectarticles of interest, and the kinds of documents (patents vs journalarticles, for example). This content can only be digested within thesubsequent models if rendered in plain text-accessible format,although there is variety in that format.
# 45The older digitized contentis available primarily in portable document format (PDF) (introducedin 1993); however, even the older content may be preserved as images,presenting an insurmountable challenge in extracting information atscale. Converting PDF to plain text relies on spatial identiﬁcation ofblocks of text in a layout-aware manner, which is still an area ofresearch.
# 46Errors may arise in terms of misplaced blocks of text andfont-conversion challenges. Most journals and publishers after themid-1990s also provide content as hypertext markup language(HTML) or extensible markup language (XML). HTML or XML oftenhas more consistency in their conversion to plain text format, but thisformat is not ubiquitous across publishers. Given the challenges asso-ciated with PDF conversion, nearly all reports of text mining of mate-rials science texts have been on articles available in markuplanguage.
# 47,48
# Acquiring information from patents provides another way toobtain content, given patent accessibility and centralized hostingby country-speciﬁc patent ofﬁces. However, patent authors oftenseek to protect their knowledge from being fully disclosed, and so,these texts may have even more implicit information than journalarticles. Patents relevant to materials science have a closely deﬁnedstructure and style of presentation;
# 49in particular, the examplesection mirrors the synthesis section, so they can be interpretedwith a high degree of accuracy. Patents will not be a focus of themethodology discussion going forward in this text, but they havebeen used in biology and chemistry applications with somefrequency.
# 50
# The downloaded content consists of article text and meta-data (journal name, title, abstract, and author names). The meta-data provide value in databasing the content, as well as beinghigh-level information that can inform entity recognition asdescribed below; it is typically more structured than the docu-ment content.B. Text preprocessing and tokenizationOnce the content has been obtained, three main activities are usedto manipulate the information contained within the text: entity extrac-tion, entity relation, and entity linking. This overall ﬂow begins with aseries of steps that preprocess the text of the article to enable identiﬁca-tion of the desired information. Preprocessing will vary according to theorder of events and the tools used for each stage. A low-level, but critical,step is character encoding, establishing the way that the characters arerepresented.Tokenization(a form of preprocessing) segments text intothe relevant sentences, phrases, words, or word pieces, to be processedindividually or as a sequence. Punctuation marks are the obviousapproach to identify sentences, but the language of the scientiﬁc domainis often complicated by terms that are composed of multiple words, sym-bols, and other types of structural entities, which, therefore, requiresspecialized tokenization pipelines. Some examples of this challenge withchemical and material notation include the uses of commas:(Y,In)BaCo3ZnO7;periods:(La 0.8Sr0.2)0.97MnO3or CuSO4/C15H2O;hyphens: (1/C0x)Pb(Zr
# 0.52Ti0.48)O3/C0xBaTiO3or Ti-64 (common term forTi
# 90Al6V4alloy); and colons: LiSr1/C0xPO4:Eux. Using materials domain-speciﬁc tokenization has been shown to be important for successful NLPof materials texts as it can have a signiﬁcant impact on downstreamactivities.
# 47,48,51Common tokenizers for the scientiﬁc literature includethose available within the software:OSCAR4,
# 34ChemDataExtractor,33
# ChemSpot,32andBANNER’ssimple tokenizer.27More general tokenizersthat may also be used or adapted for the scientiﬁc literature include thoseby SpaCy and the Penn Treebank tokenizer.Dependency-based parsing of sentencesandpart-of-speech(POS)tagging identify the syntactic structure of a sentence. Current state-of-the-art approaches use neural algorithms, including sequential andbidirectional modeling; however, these algorithms rely on largervolumes of training data and corpora than is typical for speciﬁc caseswithin materials science.
# 52Nonetheless, some models such as bidirec-tional encoder representations from transformers (BERT)
# 53haveshown the ability to adapt readily to certain tasks using datasets on theorder of thousands of documents, simply by “swapping out” the ﬁnallayers of the model to a task-speciﬁc architecture (e.g., part-of-speechtagging during parsing). Further-distilled models, such asDistilBERT,
# 54may improve this ability to adapt to thousands ofdocument-sized datasets, as there are fewer parameters to ﬁne tuneduring domain adaptation. Note that we will discuss the role of BERTand other word embedding models below.When compared to general-purpose text, a scientiﬁcdependency-parse should learn speciﬁc sentence structures and pat-terns, such as an extensive use of passive and past tense, limited use ofpronouns, and depersonalization of a sentence.
# 55The accurate con-struction of dependency-based parse trees is highly sensitive to thepunctuation and correct usage of the word forms, especially verbtenses. These aspects of the grammar are often neglected in scientiﬁcpublications, making it difﬁcult to use standard well-developed algo-rithms and tools for text mining. To date, there have not been develop-ments to address these caveats for scientiﬁc text.C. Document segmentation and paragraphclassificationNLP can afford better accuracy when one operates only withinspeciﬁc parts of the article, such as the abstract, main text body, tables,
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-5Published under license by AIP Publishing
# or ﬁgures, depending on the area of inquiry. This approach not onlyhelps computationally but can also increase the uniformity of thedesired extracted text. Matching regular expressions to identify sectionheaders provides an easy guide, and this can be done simply usingstring matching within a set of text or regular expression (regex)coding, although the variation in the application of headers by pub-lishers can present a challenge even in this straightforward activity.Huo and colleagues have recently applied probabilistic methods, suchas latent Dirichlet allocation (LDA), across several million articles touse unsupervised approaches to identify experimental steps implied insentences.
# 56LDA provided a probabilistic topic distribution for eachsentence. These authors, then, applied random decision forests, usingthe topic n-gram as the feature, to classify different types of synthesisprocedures; this required annotation of only a few hundred para-graphs. Another feature of this work is that the authors were able toconstruct a Markov chain representation of the material synthesis ﬂowchart.As an alternative to the unsupervised approaches discussed,Hiszpanskiet al.used a supervised ML approach to evaluate everysentence within an article and extract solution-based synthesis proto-cols.
# 57Speciﬁcally, by iterative rounds of training with human-annotated sentences, they trained a logistic regression classiﬁer thatyields the likelihood of a given sentence describing solution-based syn-thesis protocols based on the words present within the sentence. Asmay be expected from scientiﬁc writing conventions, past tense verbs,unit terms (e.g., ml and min), and chemicals are weighed heavily asbeing indicative of a synthesis description. Surprisingly, functionwords such as “the,” “of,” “then,” and “and,” which are normally ﬁl-tered out from text as “stop words” in nonscientiﬁc applications, occurmore commonly in synthesis protocols and are important in distin-guishing sentences that concern synthesis or otherwise. This observa-tion points out again how traditional NLP approaches may need to bemodiﬁed when these tools are translated in their application from gen-eral texts to the scientiﬁc literature.D. Named entity recognition (NER)Each of the preprocessing steps described above enable the heartof the text-extraction activity, NER, which identiﬁes the objects ofsemantic value by recognizing and classifying concepts mentioned inthe text. Entities are useful in and of themselves for researchers to mapto properties, to ﬁnd similar compounds, or to incorporate in annota-tion labeling. Historically, immense effort has gone into NER for themedical domain, extracting symptoms, diagnoses, and medicationsfrom text.
# 27The chemistry domain has expended signiﬁcant effort inNER, but even state-of-the-art NER systems do not typically performwell when applied to different domains, and effort is required to createquality data for trainable statistical NER systems.
# 58
# NER is an area where the materials community is clearly in itsinfancy. There is a need for training data to develop entity-recognitionmodels. Where knowledge bases exist already for a ﬁeld, training maybe done using distant supervision models that map known entities andrelations onto unstructured text. In the computer-science community,this activity is supported by “all community” developed learning tasksthat are orchestrated through conferences in the ﬁeld; these tend totackle signiﬁcant challenges along a roadmap, thereby making con-certed progress as a domain.
# 59There is no equivalent yet in the materi-als space.The general methods for NER range from dictionary look-ups,rule-based, and machine-learned approaches. Typical pipelines usedin the materials science domain include hybrids of all three of theseapproaches. Hybrid systems provide a balance of precision with com-putational efﬁciency, where only those cases that cannot be handledby dictionaries or rules pass to ML approaches to make efﬁcient use ofannotated data. Dictionary look-ups include material composition,chemical element names, properties, as well as processes and experi-mental parameters.Hand-crafted rule/knowledge-based methods are a collection ofrules or speciﬁcations deﬁning how to handle relative ordering andmatching among those rules. Rules may be developed through corpus-based systems that require examining several cases to obtain thepatterns or via domain knowledge understanding of nomenclature con-vention. To overcome the time intensive nature of rule development,strategies have been developed to learn rules through small collectionsof seed examples that begin from very high precision rules and learn togeneralize orvice versa. Examples of these approaches includeLeadMine,60which uses naming convention rules, ChemicalTagger,61
# which parses experimental synthesis sections of chemistry texts, andportions of ChemDataExtractor, which uses nested rules. For example,when researchers extended ChemDataExtractor for use in magneticmaterials, additions were made for domain-speciﬁc parsing rulesincluding off-stoichiometry and relevant terms associated with thedomain of interest (in this case magnetic materials such as ferroelectricsand ferrites).
# 51
# Finally, at the other end of the continuum of NER, approachesare ML-based statistical models, which use a feature-based representa-tion of observed data to recognize speciﬁc entity names. These modelstypically depend on sets of annotated documents, which rely on anno-tated corpora and the development of metrics for inter-annotatoragreement where multiple annotators are involved. Given that a sen-tence is represented as a sequence of words, it is insufﬁcient to con-sider only the current word class; therefore, sequential (and typicallybidirectional) models are necessary to consider the proceeding, cur-rent, and following word. While rule-based approaches are tedious todevelop and not easily generalized, supervised ML models, in contrast,require substantial expert-annotated data for training along withdetailed annotation guidelines. ML models invite careful considerationof the types of classes that are identiﬁed and the order in which labelsare classiﬁed. Initial NER work speciﬁc to the materials domain wasperformed by Kimet al.
# 47Kononovaet al.further built upon thiswork through a two-step materials entity recognition
# 48using the bidi-rectional long short-term memory network with the conditional ran-dom ﬁeld neural network.As alluded to above, the degree of supervision within NLP isoften modulated by word vector representations that capture the syn-tactic and semantic word relationships, the so-called “wordembeddings.” Word embeddings are a learned continuous vector rep-resentation, which encode the local word context; these can, then, beanalyzed to capture distributional similarities of words. These modelsmay be intrinsic, wherein they identify semantic relations, or extrinsic.Character-based word representation models help with “what does theword look like”; these use the individual character of a token to gener-ate the token vector representation and include morphemes (sufﬁxesand preﬁxes) and morphological inﬂections (number and tense). Theeffectiveness of word vectors depends not only on the training
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-6Published under license by AIP Publishing
# algorithm and hyperparameters but obviously also on the source data.Recent work explored the impact of similarity between pre-trainingdata and target task, particularly in the area of word embeddings.
# 62
# This work proposed to select pre-trained data using the target vocabu-lary covered rate (percentage of the target vocabulary that is also pre-sent in the source data) and language-model perplexity (if the modelﬁnds a sentence very unlikely, in other words dissimilar from the datawhere this language model is trained on, it will assign a low probabilityand therefore high perplexity). The authors found that the effective-ness of pre-trained word vectors depends on whether the source datahave a high vocabulary intersection with target data, while pre-trainedlanguage models can gain more beneﬁts from a similar source. Wenote, therefore, that the choice of corpus used for the training processis critical, pointing to the quality of text and domain-speciﬁcityrequirements.
# 38A range of word-embedding models have been usedin the materials community to date and vary with aspects of the corpusthat they are trained on; for example, Word2Vec
# 63is trained just onthe solid-state synthesis paragraphs vs the contextual model, which istrained on full text.
# 64Other word embedding models that have beenused in the materials science domain include FastText,
# 65Embeddingsfrom Language Models (ELMo),
# 66and BERT.53,67
# Materials-speciﬁc challenges to NER will vary by the subdomain.These include subtleties associated with the property, context, andreporting of the underlying measurement. For example, within thework from Auduset al.on the NLP of polymers,
# 68,69the authors haveundertaken speciﬁc NER efforts related to that domain, termedpolyNER. A synthetic polymer is rarely a single entity and is describedinstead by distributions of molecular weight, often in conjunction withnonstandard naming conventions or trade names.
# 68Thus, polyNERfocuses on a necessary pretreatment for polymer entity recognition,highlighting the challenges of generalizing NER tools across disparatedomains within materials science. As another example, in work pur-sued by Kononovaet al.on solid-state synthesis of inorganic materials,material entries were processed with a material parser that convertedstrings for a material into a chemical formula, which in turn was splitinto elements and stoichiometric balances. Then, the authors obtainedbalanced reactions from precursors and target materials by solving asystem of linear equations; this included a set of open compounds thatcan be released or absorbed, which were inferred based on the compo-sition of precursor and target materials.
# 48
# Often, these approaches require hybrid system development,where the computer automates one aspect of the activity and humanintervention enables precise execution. For the polymer extractionwork, the NLP-based extraction process identiﬁed candidates withinthe article and subsequent automated and crowd-sourcing curationsteps processed these candidates. There are several ways to formalizethe role that a human might play in these activities.
# 70,71Approachescan leverage word-embedding models to establish entity-rich corpora,the so-called candidate generation, for expert labeling, which feedsinto a context-based word-vector classiﬁer.
# 69Researchers have alsopursued active learning with maximum-entropy uncertainty samplingto achieve valuable annotations from experts to improve performance,but this proved time intensive to pursue.
# 72Roles for hybrid systemsalso include establishing dictionaries for stop words and rules to detectsystematic names.An additional challenge in the materials community is multi-word tokens. Huang and Ling recently proposed multi-wordidentifying and representing methods. This involves recognizing themulti-word phrases in the chemical literature through unsupervisedmethods and then representing the phrases in the vocabulary.73
# Typically, word embedding is performed after tokenization withphrase representation obtained based on a post-vector addition. Inthis method, a new step is incorporated to identify multi-word phrasesand add the detected terms to the vocabulary. In this case, wordembedding is performed afterwards at the phrase level. Huang andLing’s computationally intense approach starts from tokenized andtrimmed single words and sentence context. Then, they use scoringfunctions to identify bigrams, repeating this process up to n-grams,and then move to phrase-level word embedding.
# 74,75
# E. Entity relation extraction and linkingEntity relation extraction is the activity that identiﬁes relationsbetween entities mentioned in a given document. It is primarily donein post-processing steps after NER. Entities extracted can also belinked to their properties or co-occurrence with other entities, whichallows new knowledge between them to be identiﬁed. Efforts have pri-marily focused on the co-occurrence of entities within a few sentencesof each other, although there is a need to extend this to a fulldocument.Within materials science, most entity-relation extraction occursthrough dependency parsing. More direct supervised ML-basedapproaches would require the development of larger annotated cor-pora and quantifying similarity by computing representation similar-ity. One approache used in materials examples concerns Snowballmethods, which include seed examples of known positive relation-ships. Based on locating sentences with these seed examples, typicalpatterns are learned using clustering of textual similarity.
# 61By compar-ing unseen sentences to learned patterns, new relationships can beidentiﬁed based on a threshold minimum level of similarity. Thesemethods have been extended recently within ChemDataExtractor toolsusing a modiﬁed Snowball algorithm.
# 51The original Snowball algo-rithm uses several thousand seed examples.
# 76For the modiﬁedSnowball algorithm, the quaternary relationships included the prop-erty speciﬁer, chemical entity mention, property value, and thenunit.
# 51Named entity linking, then, connects information extractedfrom text with data stored in curated databases where the challengesare to delineate entities that are different from those that are synonymsand should be linked to one unique identiﬁer.There are several issues to consider after initially applying NLPtechniques to scientiﬁc text. First, whether or not the data are extractedaccurately. Second, are the data reported correctly. Third, are databeing reported with sufﬁcient details to warrant these efforts. As theprocess of text mining proceeds down the pipeline shown inFig. 2,theaccuracy of the extracted data decays rapidly, and noise accumulates.Hence, the choice between having higher precision within a set ofextracted data vs having a larger dataset size becomes pivotal becausethis choice will signiﬁcantly affect the results of the data mining. Kimet al.showed that even when using millions of raw papers as a startingposition, numbers may drop to just hundreds of thousands of papersdepending on the speciﬁc topic.
# 47Data loss arises not only due toimperfections of the extraction methods but also, oftentimes, due tothe misrepresentation of the original information. A prominent exam-ple is referencing a previously published procedure or data analysisinstead of providing its description in the current paper. The use of
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-7Published under license by AIP Publishing
# nonstandard abbreviations, acronyms, and terms also signiﬁcantlyaffects the amount of false negative outcomes, as these abbreviationscomplicate the linking of the information from different parts of thetext.All these places for data loss point to the signiﬁcant role ofoutliers and how frequently a data point is occurring, as well ashow they are treated afterwards. The pursuit of ground truth forsupervised ML within NLP is costly and time-consuming since it isbased on the limited annotated documents thus far as discussedabove. Whether or not accuracy that is sufﬁcient for the spread ofgoals of NLP and text mining in materials science can be achievedis still an open question.F. Conceptual networkSeparate from the NLP pipeline described above, the use of text-based approaches to generally learn a ﬁeld has been an area of interestlinked to the concept of ontologies, as described above. A high-levelworkﬂow for ontology generation is as follows: ﬁrst, generate conceptlists through expert input and comparisons between a curated refer-ence list and a random set of scientiﬁc documents. Then, use methods,such as bag-of-words, to populate the ontology. Recent work used ahierarchical LDA, which learned an overall structure from the dataand generated a tree of classes that could be used for searching terms,annotation, and standardization of metadata.
# 77There are a few inter-esting ways to generate these concept lists. The work by Krenn andZelinger analyzed trends in quantum physics by generating a conceptlist through human-expert input that is expanded by Rapid AutomaticKeyword Extraction to a term list; this is, then, fed into a comprehen-sive corpus to establish links between each of the terms. To projectfuture directions of research, they performed a link-prediction task toask which new link will be formed between unconnected vertices giventhe current network. This was done using an artiﬁcial neural networkwith four fully connected layers, which ranked unconnected pairs ofconcepts and further extended this approach to identify pairs withexceptional network properties.
# 78 IV. RESOURCES AND TOOLS FOR NLPGiven the methods described above, a section is provided here,which summarizes some helpful resources and tools, including a cov-erage of the tools most commonly used in NLP for materials.Table Ilists the most common NER toolkits publicly and freely available andthe information that they are capable of extracting. Most have beenfocused on capabilities to extract entities from body text, but manyhave expanded efforts to extract tables as well. Several also have a focuson extracting biology-relevant information, which stems from the ear-lier leading NLP efforts in life sciences. The groups that developedthese tools have taken varied approaches, tailored to their speciﬁcsub-ﬁeld of literature. The tools typically vary with the tokenizers andtechniques that they use to identify chemicals, which often involve acombination of dictionaries, hand-crafted rules/patterns, andPOS-tagging methods, as previously discussed.Researchers are likely to be interested in extracting categories ofinformation, which are speciﬁc to their research topic and beyond, forwhich there are readily available tools shown inTable I.Ifthecategoryof information that is desired has a formulaic representation, or it hasa limited number of possible ways of being expressed, then rather sim-ple pattern- or dictionary-based approaches can be created to extractthis new category of information. When these more straightforwardmethods fail, then ML-based models can be developed, such as theCRF models for chemical-entity recognition, as previously discussed.Common packages for developing such NLP models include NaturalLanguage Toolkit (NLTK),
# 83SpaCy,84Stanford CoreNLP,85
# AllenNLP,86and openNLP.87
# In addition to the plethora of software packages for NLP, recentdevelopments in word representation research have led to generalizedmodels that may be rapidly ﬁne-tuned to domains of interest. A nota-ble example is BERT,
# 53which has been ﬁne-tuned to scientiﬁc text toproduce SciBERT;
# 67such models may ultimately advance the accuracyof entity recognition for chemicals and materials.Moreover, other advances in NLP research beyond word repre-sentation and subsequent supervised tasks (i.e., classiﬁcation) may
#
# TABLE I.Tools available for natural language processing in the materials discipline.
# Entity recognition toolkits Information capable of extractingApproach for named entity recognition (chemistryfocused)ChemDataExtractor
# ...
# 56H. Huoet al., “Semi-supervised machine-learning classiﬁcation of materialssynthesis procedures,”NPJ Comput. Mater.5, 1–7 (2019).
# 57A. M. Hiszpanskiet al., “Nanomaterials synthesis insights from machinelearning of scientiﬁc articles by extracting, structuring, and visualizing knowl-edge,”J. Chem. Inf. Model.60, 2876 (2020).
# 58M. Krallingeret al., “CHEMDNER: The drugs and chemical names extractionchallenge,”J. Cheminf.7, 1–11 (2015).
# 59E. F. T. K. Sang and F. De Meulder, “Introduction to the CoNLL-2003 sharedtask: Language-independent named entity recognition,”arXiv:cs/0306050(2003).
# 60D. M. Lowe and R. A. Sayle, “LeadMine: A grammar and dictionary drivenapproach to entity recognition,” J. Cheminf.7, 1–9 (2015).
# 61L. Hawizy, D. M. Jessop, N. Adams, and P. Murray-Rust, “ChemicalTagger: Atool for semantic text-mining in chemistry,”J. Cheminf.3, 17 (2011).
# 62X. Dai, S. Karimi, B. Hachey, and C. Paris, “Using similarity measures toselect pretraining data for NER,” in Proceedings of the 2019 Conference ofthe North American Chapter of the Association for ComputationalLinguistics: Human Language Technologies, Volume 1 (Long and ShortPapers) (2019), pp. 1460–1470.
# 63T. Mikolov, I. Sutskever, K. Chen, G. S. Corrado, and J. Dean, “Distributedrepresentations of words and phrases and their compositionality,” inAdvanceNeural Information Processing Systems(2013), pp. 3111–3119.
# 64E. Kimet al., “Inorganic materials synthesis planning with literature-trainedneural networks,”J. Chem. Inf. Model.60, 1194 (2020).
# 65P. Bojanowski, E. Grave, A. Joulin, and T. Mikolov, “Enriching word vectorswith subword information,”Trans. Assoc. Comput. Linguist.5, 135–146(2017).
# 66M. Peterset al., “Deep contextualized word representations,” in Proceedingsof the 2018 Conference of the North American Chapter of the Association forComputational Linguistics: Human Language Technologies, Volume 1 (LongPapers) (2018), pp. 2227–2237.
# 67I. Beltagy, A. Cohan, and K. Lo, “SciBERT: Pretrained contextualized embed-dings for scientiﬁc text,”arXiv:1903.10676(2019).
# 68D. J. Audus and J. J. De Pablo, “Polymer informatics: Opportunities andchallenges,”ACS Macro Lett.6, 1078–1082 (2017).
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-17Published under license by AIP Publishing
# 69R. B. Tchouaet al., “Creating training data for scientiﬁc named entity recog-nition with minimal human effort,”Lect. Notes Comput. Sci.11536, 398–411(2019).
# 70C. Seifertet al., “Crowdsourcing fact extraction from scientiﬁc literature,” inInternational Workshop on Human-Computer Interaction and KnowledgeDiscovery in Complex, Unstructured, Big Data(Springer, 2013), pp. 160–172.
# 71J. Takis, A. Q. M. S. Islam, C. Lange, and S. Auer, “Crowdsourced semanticannotation of scientiﬁc publications and tabular data in PDF,” in Proceedingsof the 11th International Conference on Semantic Systems (2015), pp. 1–8.
# 72R. Tchouaet al., “Active learning yields better training data for scientiﬁcnamed entity recognition,” in Proceedings of the IEEE 15th InternationalConference on eScience, eScience 2019 (2019), pp. 126–135.
# 73L. Huang and C. Ling, “Representing multiword chemical terms throughphrase-level preprocessing and word embedding,”ACS Omega4,18510–18519 (2019).
# 74X. Gao, R. Tan, and G. Li, “Research on text mining of material science basedon natural language processing,”IOP Conf. Ser. Mater. Sci. Eng.768, 72094(2020).
# 75D. Zeng, K. Liu, S. Lai, G. Zhou, and J. Zhao, “Relation classiﬁcation via con-volutional deep neural network,” in Proceedings of COLING 2014, the 25thInternational Conference on Computational Linguistics: Technical Papers(2014), pp. 2335–2344.
# 76E. Agichtein and L. Gravano, “Snowball: Extracting relations from largeplain-text collections,” in Proceedings of the Fifth ACM Conference onDigital Libraries (2000), pp. 85–94.
# 77O. Hakimiet al., “The devices, experimental scaffolds, and biomaterials ontol-ogy (DEB): A tool for mapping, annotation, and analysis of biomaterialsdata,”Adv. Funct. Mater.30, 1909910–1909913 (2020).
# 78M. Krenn and A. Zeilinger, “Predicting research trends with semantic andneural networks with an application in quantum physics,”Proc. Natl. Acad.Sci. U. S. A.117, 1910 (2019).
# 79M. Khabsa and C. L. Giles, “Chemical entity extraction using CRF and anensemble of extractors,”J. Cheminf.7, S12 (2015).
# 80P. Mitra, C. L. Giles, B. Sun, and Y. Liu, “Chemxseer: A digital library anddata repository for chemical kinetics,” in Proceedings of the ACM FirstWorkshop on CyberInfrastructure: information Management in eScience(2007), pp. 7–10.
# 81Y. Liu, K. Bai, P. Mitra, and C. L. Giles, “Tableseer: Automatic table metadataextraction and searching in digital libraries,” in Proceedings of the 7th ACM/IEEE-CS Joint Conference on Digital Libraries (2007), pp. 91–100.
# 82D. M. Lowe, N. M. O’Boyle, and R. A. Sayle, “Efﬁcient chemical-disease iden-tiﬁcation and relationship extraction using Wikipedia to improve recall,”Database2016, baw039.
# 83S. Bird, E. Loper, and E. Klein, seehttp://www.nltk.orgfor Natural languagetoolkit, 2009.
# 84Seehttps://spacy.io/for SpaCy.
# 85Seehttps://stanfordnlp.github.io/CoreNLP/for CoreNLP.
# 86Seehttps://allennlp.org/for AllenNLP.
# 87Seehttps://opennlp.apache.org/for OpenNLP.
# 88M. Ebraheem, S. Thirumuruganathan, S. Joty, M. Ouzzani, and N. Tang,“DeepER—Deep entity resolution,”arXiv:1710.00597(2017).
# 89S. Mudgalet al., “Deep learning for entity matching: A design spaceexploration,” in Proceedings of the 2018 International Conference onManagement of Data (2018), pp. 19–34.
# 90Seehttps://brat.nlplab.org/for BRAT.
# 91Seehttps://prodi.gy/for Prodigy.
# 92Seehttps://webanno.github.io/webanno/for Webanno.
# 93Seehttp://mitre.github.io/callisto/for Callisto.
# 94S. Mysoreet al., “The materials science procedural text corpus: Annotatingmaterials synthesis procedures with shallow semantic structures,” inProceedings of the 13th Linguistic Annotation Workshop (2019).
# 95F. Kuniyoshi, K. Makino, J. Ozawa, and M. Miwa, “Annotating and extractingsynthesis process of all-solid-state batteries from scientiﬁc literature,” inProceedings of the 12th Conference on Language Resources and Evaluation(LREC 2020) (2020).
# 96A. Friedrichet al., “The SOFC-Exp corpus and neural approaches to informa-tion extraction in the materials science domain,” in Proceedings of the 58thAnnual Meeting of the Association for Computational Linguistics (2020), pp.1255–1268.97C. Kulkarni, W. Xu, A. Ritter, and R. Machiraju, “An annotated corpus formachine reading of instructions in wet lab protocols,” in Proceedings of the2018 Conference of the North American Chapter of the Association forComputational Linguistics: Human Language Technologies, Volume 2 (ShortPapers) (2018), pp. 97–106.
# 98C. A. Aguirre, S. Coen, M. F. De La Torre, W. H. Hsu, and M. Rys, “Towardsfaster annotation interfaces for learning to ﬁlter in information extractionand search,” in CEUR Workshop Proceedings (2018), Vol. 2068.
# 99Seehttps://docs.bokeh.org/en/latest/index.htmlfor Candela.
# 100Seehttps://docs.bokeh.org/en/latest/index.htmlfor Bokeh.
# 101Seehttps://c3js.org/examples.htmlfor D3.
# 102C. Kim, A. Chandrasekaran, T. D. Huan, D. Das, and R. Ramprasad,“Polymer genome: A data-powered polymer informatics platform for propertypredictions,”J. Phys. Chem. C122, 17575–17585 (2018).
# 103S. R. Younget al., “Data mining for better material synthesis: The case ofpulsed laser deposition of complex oxides,”J. Appl. Phys.123, 1–11 (2018).
# 104E. Kimet al., “Machine-learned and codiﬁed synthesis parameters of oxidematerials,”Sci. Data4, 170127 (2017).
# 105Z. Jensenet al., “A machine learning approach to zeolite synthesis enabled byautomatic literature data extraction,”ACS Cent. Sci.5, 892 (2019).
# 106E. J. Beard, G. Sivaraman,/C19A. V/C19azquez-Mayagoitia, V. Vishwanath, and J. M.Cole, “Comparative dataset of experimental and computational attributes ofUV/vis absorption spectra,”Sci. Data6, 1–11 (2019).
# 107R. B. Tchouaet al., “Towards a hybrid human-computer scientiﬁc informationextraction pipeline,” in Proceedings of the IEEE 13th InternationalConference on eScience, eScience 2017 (2017), pp. 109–118.
# 108Seehttps://maldi.nist.gov/for MALDI.
# 109D. Schwalbe-Koda, Z. Jensen, E. Olivetti, and R. G/C19omez-Bombarelli, “Graphsimilarity drives zeolite diffusionless transformations and intergrowth,”Nat.Mater.18, 1177–1181 (2019).
# 110P. B. de Castroet al., “Machine-learning-guided discovery of the gigantic mag-netocaloric effect in HoB
# 2near the hydrogen liquefaction temperature,”NPGAsia Mater.12, 1–7 (2020).
# 111L. W. Jones, “Liquid hydrogen as a fuel for the future,”Science174, 367–370(1971).
# 112J. M. Cole, “A design-to-device pipeline for data-driven materials discovery,”Acc. Chem. Res.53, 599–610 (2020).
# 113E. Kim, K. Huang, S. Jegelka, and E. Olivetti, “Virtual screening of inorganicmaterials synthesis parameters with deep learning,”NPJ Comput. Mater.3,53(2017).
# 114J. B. Voytek and B. Voytek, “Automated cognome construction and semi-automated hypothesis generation,”J. Neurosci. Methods208, 92–100 (2012).
# 115D. Junget al., “ChartSense: Interactive data extraction from chart images,” inProceedings of the 2017 CHI Conference on Human Factors in ComputingSystems (2017), pp. 6706–6717.
# 116X. Liu, D. Klabjan, and P. NBless, “Data extraction from charts via single deepneural network,”arXiv:1906.11906(2019).
# 117L. Gao, X. Yi, Z. Jiang, L. Hao, and Z. Tang, “ICDAR2017 competition on pageobject detection,” in2017 14th IAPR International Conference on DocumentAnalysis and Recognition (ICDAR)(IEEE, 2017), Vol. 1, pp. 1417–1422.
# 118L. Gaoet al., “ICDAR 2019 competition on table detection and recognition(CTDAR),” in2019 International Conference on Document Analysis andRecognition (ICDAR)(IEEE, 2019), pp. 1510–1515.
# 119B. L. DeCost, B. Lei, T. Francis, and E. A. Holm, “High throughput quantita-tive metallography for complex microstructures using deep learning: A casestudy in ultrahigh carbon steel,”arXiv:1805.08693(2018).
# 120S. M. Azimi, D. Britz, M. Engstler, M. Fritz, and F. M€ucklich, “Advanced steelmicrostructural classiﬁcation by deep learning methods,”Sci. Rep.8, 1–14(2018).
# 121J. Golaet al., “Objective microstructure classiﬁcation by support vectormachine (SVM) using a combination of morphological parameters and tex-tural features for low carbon steels,”Comput. Mater. Sci.160, 186–196 (2019).
# 122G. Robertset al., “Deep learning for semantic segmentation of defects inadvanced stem images of steels,”Sci. Rep.9, 12744 (2019).
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-18Published under license by AIP Publishing
# 123A. Maksovet al., “Deep learning analysis of defect and phase evolution duringelectron beam-induced transformations in WS 2,”NPJ Comput. Mater.5,12(2019).
# 124L. Vlcek, A. Maksov, M. Pan, R. K. Vasudevan, and S. V. Kalinin, “Knowledgeextraction from atomically resolved images,”ACS Nano11, 10313–10320(2017).
# 125K. T. Mukaddem, E. J. Beard, B. Yildirim, and J. M. Cole,“ImageDataExtractor: A tool to extract and quantify data from microscopyimages,”J. Chem. Inf. Model.60, 2492 (2020).
# 126R. Smith, “An overview of the Tesseract OCR engine,”inNinth InternationalConference on Document Analysis and Recognition (ICDAR 2007)(IEEE,2007), Vol. 2, pp. 629–633.
# 127C. Dong, C. C. Loy, K. He, and X. Tang, “Image super-resolution using deepconvolutional networks,”IEEE Trans. Pattern Anal. Mach. Intell.38, 295–307(2016).
# 128C. Dong, C. C. Loy, K. He, and X. Tang, “Learning a deep convolutional net-work for image super-resolution,” inEuropean Conference on ComputerVision(Springer, 2014), pp. 184–199.
# 129M.-K. Hu, “Visual pattern recognition by moment invariants,”IRE Trans. Inf.Theory8, 179–187 (1962).
# 130H. Kim, J. Han, and T. Y.-J. Han, “Machine vision-driven automatic recogni-tion of particle size and morphology in SEM images,”Nanoscale12,19461–19469 (2020).
# 131C. Szegedy, V. Vanhoucke, S. Ioffe, J. Shlens, and Z. Wojna, “Rethinking theinception architecture for computer vision,” in Proceedings of the IEEEConference on Computer Vision and Pattern Recognition (2016), pp.2818–2826.
# 132X. Xia, C. Xu, and B. Nan, “Inception-v3 for ﬂower classiﬁcation,” in2017 2ndInternational Conference on Image, Vision and Computing (ICIVC)(IEEE,2017), pp. 783–787.
# 133E. Tran, M. B. Mayhew, H. Kim, P. Karande, and A. D. Kaplan, “Facial expres-sion recognition using a large out-of-context dataset,” in2018 IEEE WinterApplications of Computer Vision Workshops (WACVW)(IEEE, 2018), pp.52–59.
# 134W. Tatumet al., “A generalizable framework for algorithmic interpretation ofthin ﬁlm morphologies in scanning probe images,”J. Chem. Inf. Model.60,3387 (2020).
# 135J. R. McDaniel and J. R. Balmuth, “Kekule: OCR-optical chemical (structure)recognition,”J. Chem. Inf. Comput. Sci.32, 373–378 (1992).
# 136A. T. Valko and A. P. Johnson, “CLiDE Pro: The latest generation of CLiDE, atool for optical chemical structure recognition,”J. Chem. Inf. Model.49,780–787 (2009).137J. Parket al., “Automated extraction of chemical structure information fromdigital raster images,”Chem. Cent. J.3, 4 (2009).
# 138I. V. Filippov and M. C. Nicklaus, “Optical structure recognition software torecover chemical information: OSRA, an open source solution,”J. Chem. Inf.Model.49, 740–743 (2009).
# 139E. J. Beard and J. M. Cole, “ChemSchematicResolver: A toolkit to decode 2Dchemical diagrams with labels and R-groups into annotated chemical namedentities,”J. Chem. Inf. Model.60, 2059 (2020).
# 140D. Weininger, “SMILES, a chemical language and information system. 1.Introduction to methodology and encoding rules,”J. Chem. Inf. Comput. Sci.28, 31–36 (1988).
# 141P. Andersonet al., “Bottom-up and top-down attention for image captioningand visual question answering,” in Proceedings of the IEEE Conference onComputer Vision and Pattern Recognition (2018), pp. 6077–6086.
# 142K. Xuet al., “Show, attend and tell: Neural image caption generation with visualattention,” in International Conference on Machine Learning (2015), pp. 2048–2057.
# 143Y. Qian, E. Santus, Z. Jin, J. Guo, and R. Barzilay, “GraphIE: A graph-basedframework for information extraction.”arXiv:1810.13083(2018).
# 144A. Conneau, G. Lample, M. Ranzato, L. Denoyer, and H. J/C19egou, “Word trans-lation without parallel data,”arXiv:1710.04087(2017).
# 145M. T. Ribeiro, T. Wu, C. Guestrin, and S. Singh, “Beyond accuracy: Behavioraltesting of NLP models with checklist,”arXiv:2005.04118(2020).
# 146Seemits.nims.go.jpfor NIMS Materials Data Base (MatNavi).
# 147A. Halevy, P. Norvig, and F. Pereira, “The unreasonable effectiveness of data,”IEEE Intell. Syst.24, 8–12 (2009).
# 148J. S. Grosmanet al., “Eras: Improving the quality control in the annotationprocess for natural language processing tasks,”Inf. Syst.93, 101553 (2020).
# 149A. Zakutayevet al., “An open experimental database for exploring inorganicmaterials,”Sci. Data5, 180053 (2018).
# 150P. Nikolaev, D. Hooper, N. Perea-Lopez, M. Terrones, and B. Maruyama,“Discovery of wall-selective carbon nanotube growth conditions via auto-mated experimentation,”ACS Nano8, 10214–10222 (2014).
# 151Z. Liet al., “Robot-accelerated perovskite investigation and discovery(RAPID): 1. Inverse temperature crystallization,” chemRxiv.
# 152R. J. Kearsey, B. M. Alston, M. E. Briggs, R. L. Greenaway, and A. I. Cooper,“Accelerated robotic discovery of type II porous liquids,”Chem. Sci.10,9454–9465 (2019).
# 153M. D. Wilkinsonet al., “The FAIR guiding principles for scientiﬁc data man-agement and stewardship,”Sci. Data3, 160018 (2016).
# 154A. M. Clark, A. J. Williams, and S. Ekins, “Machines ﬁrst, humans second: Onthe importance of algorithmic interpretation of open chemistry data,”J. Cheminf.7, 9 (2015).
# Applied Physics ReviewsREVIEWscitation.org/journal/are
#
# Appl. Phys. Rev.7, 041317 (2020); doi: 10.1063/5.00211067, 041317-19Published under license by AIP Publishing

# %%
r.preprocess(text)
# Out:
# 'maksovet deep learning analysis defect phase evolution duringelectron beam induced transformations npj comput mater vlcek maksov pan vasudevan kalinin knowledgeextraction atomically resolved images acs nano mukaddem beard yildirim cole imagedataextractor tool extract quantify data microscopyimages chem inf model smith overview tesseract ocr engine inninth internationalconference document analysis recognition icdar ieee vol dong loy tang image super resolution using deepconvolutional networks ieee trans pattern anal mach intell dong loy tang learning deep convolutional net work image super resolution ineuropean conference computervision springer visual pattern recognition moment invariants ire trans inf theory kim han han machine vision driven automatic recogni tion particle size morphology sem images nanoscale szegedy vanhoucke ioffe shlens wojna rethinking theinception architecture computer vision proceedings ieeeconference computer vision pattern recognition xia nan inception ﬂower classiﬁcation ndinternational conference image vision computing icivc ieee tran mayhew kim karande kaplan facial expres sion recognition using large context dataset ieee winterapplications computer vision workshops wacvw ieee tatumet generalizable framework algorithmic interpretation ofthin ﬁlm morphologies scanning probe images chem inf model mcdaniel balmuth kekule ocr optical chemical structure recognition chem inf comput sci valko johnson clide pro latest generation clide atool optical chemical structure recognition chem inf model parket automated extraction chemical structure information fromdigital raster images chem cent filippov nicklaus optical structure recognition software torecover chemical information osra open source solution chem inf model beard cole chemschematicresolver toolkit decode dchemical diagrams labels groups annotated chemical namedentities chem inf model weininger smiles chemical language information system introduction methodology encoding rules chem inf comput sci andersonet bottom top attention image captioningand visual question answering proceedings ieee conference oncomputer vision pattern recognition xuet show attend tell neural image caption generation visualattention international conference machine learning qian santus jin guo barzilay graphie graph basedframework information extraction arxiv conneau lample ranzato denoyer cegou word trans lation without parallel data arxiv ribeiro guestrin singh beyond accuracy behavioraltesting nlp models checklist arxiv seemits nims jpfor nims materials data base matnavi halevy norvig pereira unreasonable effectiveness data ieee intell syst grosmanet eras improving quality control annotationprocess natural language processing tasks inf syst zakutayevet open experimental database exploring inorganicmaterials sci data nikolaev hooper perea lopez terrones maruyama discovery wall selective carbon nanotube growth conditions via auto mated experimentation acs nano liet robot accelerated perovskite investigation discovery rapid inverse temperature crystallization chemrxiv kearsey alston briggs greenaway cooper accelerated robotic discovery type porous liquids chem sci wilkinsonet fair guiding principles scientiﬁc data man agement stewardship sci data clark williams ekins machines ﬁrst humans second onthe importance algorithmic interpretation open chemistry data cheminf applied physics reviewsreviewscitation org journal appl phys rev doi published license aip publishing'

# %%
r.extract_keywords_from_text(text)

# %%
r.get_ranked_phrases()
# Out:
# ['selective carbon nanotube growth conditions via auto',
#  'chemical structure information fromdigital raster images ,” chem',
#  '“ optical structure recognition software torecover chemical information',
#  'resolution using deepconvolutional networks ,” ieee trans',
#  'atomically resolved images ,” acs nano11',
#  'maksovet al ., “ deep learning analysis',
#  'context dataset ,” in2018 ieee winterapplications',
#  'ﬂower classiﬁcation ,” in2017 2ndinternational conference',
#  'tesseract ocr engine ,” inninth internationalconference',
#  'lation without parallel data ,” arxiv',
#  'type ii porous liquids ,” chem',
#  'image captioningand visual question answering ,”',
#  'parket al ., “ automated extraction',
#  'natural language processing tasks ,” inf',
#  'optical chemical structure recognition ,” j',
#  'mated experimentation ,” acs nano8',
#  'moment invariants ,” ire trans',
#  'inverse temperature crystallization ,” chemrxiv',
#  'xuet al ., “ show',
#  'liet al ., “ robot',
#  'grosmanet al ., “ eras',
#  'andersonet al ., “ bottom',
#  'scanning probe images ,” j',
#  'annotated chemical namedentities ,” j',
#  'jpfor nims materials data base',
#  'algorithmic interpretation ofthin ﬁlm morphologies',
#  'open source solution ,” j',
#  'open chemistry data ,” j',
#  'cooper ,“ accelerated robotic discovery',
#  'ws 2 ,” npj comput',
#  'information extraction .” arxiv',
#  'sem images ,” nanoscale12',
#  'resolution ,” ineuropean conference',
#  'zakutayevet al ., “',
#  'wilkinsonet al ., “',
#  'tatumet al ., “',
#  'phase evolution duringelectron beam',
#  'data ,” ieee intell',
#  '“ rethinking theinception architecture',
#  'icdar 2007 )( ieee',
#  'encoding rules ,” j',
#  'ieee conference oncomputer vision',
#  'exploring inorganicmaterials ,” sci',
#  '“ visual pattern recognition',
#  'neural image caption generation',
#  'checklist ,” arxiv',
#  'sion recognition using',
#  '“ word trans',
#  'deep convolutional net',
#  'recognition ,” j',
#  'wacvw )( ieee',
#  'icivc )( ieee',
#  'optical chemical',
#  'open experimental database',
#  'microscopyimages ,” j',
#  'computer vision ,”',
#  'scientiﬁc data man',
#  'accelerated perovskite investigation',
#  'stewardship ,” sci',
#  'maruyama ,“ discovery',
#  '“ machines ﬁrst',
#  '“ facial expres',
#  '“ beyond accuracy',
#  '2007 ), vol',
#  '“ image super',
#  'chemical language',
#  'fair guiding principles',
#  'driven automatic recogni',
#  'decode 2dchemical diagrams',
#  'applied physics reviewsreviewscitation',
#  '9454 – 9465',
#  '783 – 787',
#  '780 – 787',
#  '740 – 743',
#  '629 – 633',
#  '6077 – 6086',
#  '52 – 59',
#  '373 – 378',
#  '31 – 36',
#  '295 – 307',
#  '2818 – 2826',
#  '2048 – 2057',
#  '19461 – 19469',
#  '184 – 199',
#  '179 – 187',
#  '10313 – 10320',
#  '10214 – 10222',
#  '“ machine vision',
#  'cole ,“ imagedataextractor',
#  '“ clide pro',
#  'computer vision workshops',
#  '2018 ), pp',
#  '2018 ), pp',
#  '2015 ), pp',
#  '2014 ), pp',
#  '2020 ); doi',
#  '2017 ), pp',
#  '2016 ), pp',
#  'rapid ): 1',
#  '8 – 12',
#  'information system',
#  '2009 ). 137j',
#  '“ learning',
#  'algorithmic interpretation',
#  '129m .- k',
#  'visualattention ,”',
#  'document analysis',
#  'quantify data',
#  'machine learning',
#  'pattern recognition',
#  'pattern recognition',
#  'international conference',
#  'structure',
#  'image super',
#  '“ smiles',
#  '“ knowledgeextraction',
#  '“ kekule',
#  '“ inception',
#  '“ graphie',
#  '“ chemschematicresolver',
#  'computer vision',
#  'latest generation',
#  '.- j',
#  '2018 ).',
#  '2018 ).',
#  '2015 ).',
#  '2014 ).',
#  'pattern anal',
#  '2017 ).',
#  '2017 ).',
#  '2016 ).',
#  '2016 ).',
#  '2009 ).',
#  '2009 ).',
#  '2009 ).',
#  '2020 ).',
#  '2020 ).',
#  '2020 ).',
#  '2020 ).',
#  '2020 ).',
#  '2020 ).',
#  'matnavi ).',
#  '2019 ).',
#  '2019 ).',
#  '1992 ).',
#  '1988 ).',
#  '1962 ).',
#  'unreasonable effectiveness',
#  'quality control',
#  'particle size',
#  'onthe importance',
#  'nlp models',
#  'induced transformations',
#  'humans second',
#  'generalizable framework',
#  'aip publishing',
#  'recognition',
#  '“',
#  '“',
#  'ocr',
#  'image',
#  'nims',
#  'discovery',
#  '2',
#  'pp',
#  'vision',
#  'intell',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'j',
#  'comput',
#  'comput',
#  'chem',
#  'chem',
#  'chem',
#  'chem',
#  'chem',
#  'chem',
#  'chem',
#  'sci',
#  'sci',
#  'sci',
#  'cole',
#  'clide',
#  '12',
#  '1',
#  'inf',
#  'inf',
#  'inf',
#  'inf',
#  'inf',
#  'inf',
#  'inf',
#  'inf',
#  'k',
#  'k',
#  'k',
#  'z',
#  'z',
#  'yildirim',
#  'xu',
#  'xia',
#  'x',
#  'x',
#  'wu',
#  'work',
#  'wojna',
#  'williams',
#  'weininger',
#  'wall',
#  'vlcek',
#  'vasudevan',
#  'vanhoucke',
#  'valko',
#  'v3',
#  'v',
#  'v',
#  'v',
#  'tran',
#  'top',
#  'toolkit',
#  'tool',
#  'tion',
#  'theory8',
#  'terrones',
#  'tell',
#  'tang',
#  'tang',
#  'szegedy',
#  'syst',
#  'syst',
#  'springer',
#  'smith',
#  'singh',
#  'shlens',
#  'santus',
#  'ribeiro',
#  'rev',
#  'ranzato',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'r',
#  'qian',
#  'proceedings',
#  'proceedings',
#  'phys',
#  'pereira',
#  'perea',
#  'pan',
#  'p',
#  'p',
#  'p',
#  'overview',
#  'osra',
#  'org',
#  'norvig',
#  'nikolaev',
#  'nicklaus',
#  'nan',
#  'n',
#  'mukaddem',
#  'morphology',
#  'model',
#  'model',
#  'model',
#  'model',
#  'model',
#  'methodology',
#  'mcdaniel',
#  'mayhew',
#  'mater',
#  'maksov',
#  'mach',
#  'loy',
#  'loy',
#  'lopez',
#  'license',
#  'large',
#  'lample',
#  'labels',
#  'l',
#  'l',
#  'kim',
#  'kim',
#  'kearsey',
#  'karande',
#  'kaplan',
#  'kalinin',
#  'journal',
#  'johnson',
#  'jin',
#  'ioffe',
#  'introduction',
#  'improving',
#  'ieeeconference',
#  'hu',
#  'hooper',
#  'han',
#  'han',
#  'halevy',
#  'h',
#  'h',
#  'guo',
#  'guestrin',
#  'groups',
#  'greenaway',
#  'graph',
#  'go',
#  'g',
#  'filippov',
#  'f',
#  'extract',
#  'ekins',
#  'e',
#  'e',
#  'e',
#  'dong',
#  'dong',
#  'denoyer',
#  'defect',
#  'data5',
#  'data3',
#  'conneau',
#  'computing',
#  'computervision',
#  'clark',
#  'cheminf',
#  'cent',
#  'c19egou',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'c',
#  'briggs',
#  'behavioraltesting',
#  'beard',
#  'beard',
#  'basedframework',
#  'barzilay',
#  'balmuth',
#  'b',
#  'b',
#  'b',
#  'b',
#  'b',
#  'attention',
#  'attend',
#  'atool',
#  'appl',
#  'annotationprocess',
#  'alston',
#  'agement',
#  '93',
#  '9',
#  '7',
#  '7',
#  '60',
#  '60',
#  '60',
#  '5',
#  '5',
#  '49',
#  '49',
#  '4',
#  '38',
#  '3387',
#  '32',
#  '3',
#  '28',
#  '2492',
#  '24',
#  '2059',
#  '2005',
#  '19published',
#  '1810',
#  '180053',
#  '1710',
#  '160018',
#  '154a',
#  '153m',
#  '152r',
#  '151z',
#  '150p',
#  '149a',
#  '148j',
#  '147a',
#  '146seemits',
#  '145m',
#  '144a',
#  '143y',
#  '142k',
#  '141p',
#  '140d',
#  '139e',
#  '138i',
#  '136a',
#  '135j',
#  '134w',
#  '133e',
#  '132x',
#  '131c',
#  '130h',
#  '13083',
#  '128c',
#  '127c',
#  '126r',
#  '125k',
#  '124l',
#  '123a',
#  '1063',
#  '101553',
#  '10',
#  '10',
#  '041317',
#  '041317',
#  '04118',
#  '04087',
#  '00211067']

# %%
r.get_ranked_phrases_with_scores()
# Out:
# [(49.0, 'selective carbon nanotube growth conditions via auto'),
#  (45.366666666666674,
#   'chemical structure information fromdigital raster images ,” chem'),
#  (44.87499999999999,
#   '“ optical structure recognition software torecover chemical information'),
#  (38.7952380952381,
#   'resolution using deepconvolutional networks ,” ieee trans'),
#  (34.11666666666667, 'atomically resolved images ,” acs nano11'),
#  (33.66666666666667, 'maksovet al ., “ deep learning analysis'),
#  (33.2952380952381, 'context dataset ,” in2018 ieee winterapplications'),
#  (32.86666666666667,
#   'ﬂower classiﬁcation ,” in2017 2ndinternational conference'),
#  (32.36666666666667,
#   'tesseract ocr engine ,” inninth internationalconference'),
#  (31.366666666666667, 'lation without parallel data ,” arxiv'),
#  (31.2, 'type ii porous liquids ,” chem'),
#  (31.066666666666666, 'image captioningand visual question answering ,”'),
#  (30.5, 'parket al ., “ automated extraction'),
#  (28.422222222222224, 'natural language processing tasks ,” inf'),
#  (27.122619047619047, 'optical chemical structure recognition ,” j'),
#  (25.366666666666667, 'mated experimentation ,” acs nano8'),
#  (24.866666666666667, 'moment invariants ,” ire trans'),
#  (24.866666666666667, 'inverse temperature crystallization ,” chemrxiv'),
#  (23.5, 'xuet al ., “ show'),
#  (23.5, 'liet al ., “ robot'),
#  (23.5, 'grosmanet al ., “ eras'),
#  (23.5, 'andersonet al ., “ bottom'),
#  (22.997619047619047, 'scanning probe images ,” j'),
#  (22.414285714285715, 'annotated chemical namedentities ,” j'),
#  (22.166666666666668, 'jpfor nims materials data base'),
#  (22.0, 'algorithmic interpretation ofthin ﬁlm morphologies'),
#  (21.58095238095238, 'open source solution ,” j'),
#  (20.747619047619047, 'open chemistry data ,” j'),
#  (20.666666666666664, 'cooper ,“ accelerated robotic discovery'),
#  (20.2, 'ws 2 ,” npj comput'),
#  (18.833333333333332, 'information extraction .” arxiv'),
#  (18.616666666666667, 'sem images ,” nanoscale12'),
#  (18.366666666666667, 'resolution ,” ineuropean conference'),
#  (17.5, 'zakutayevet al ., “'),
#  (17.5, 'wilkinsonet al ., “'),
#  (17.5, 'tatumet al ., “'),
#  (16.0, 'phase evolution duringelectron beam'),
#  (15.961904761904762, 'data ,” ieee intell'),
#  (15.5, '“ rethinking theinception architecture'),
#  (15.261904761904763, 'icdar 2007 )( ieee'),
#  (15.247619047619049, 'encoding rules ,” j'),
#  (15.095238095238095, 'ieee conference oncomputer vision'),
#  (14.866666666666667, 'exploring inorganicmaterials ,” sci'),
#  (14.625, '“ visual pattern recognition'),
#  (14.2, 'neural image caption generation'),
#  (12.2, 'checklist ,” arxiv'),
#  (11.625, 'sion recognition using'),
#  (11.5, '“ word trans'),
#  (11.0, 'deep convolutional net'),
#  (10.872619047619049, 'recognition ,” j'),
#  (10.761904761904763, 'wacvw )( ieee'),
#  (10.761904761904763, 'icivc )( ieee'),
#  (10.5, 'optical chemical'),
#  (10.333333333333332, 'open experimental database'),
#  (10.247619047619047, 'microscopyimages ,” j'),
#  (10.2, 'computer vision ,”'),
#  (10.166666666666668, 'scientiﬁc data man'),
#  (10.0, 'accelerated perovskite investigation'),
#  (9.866666666666667, 'stewardship ,” sci'),
#  (9.666666666666666, 'maruyama ,“ discovery'),
#  (9.5, '“ machines ﬁrst'),
#  (9.5, '“ facial expres'),
#  (9.5, '“ beyond accuracy'),
#  (9.5, '2007 ), vol'),
#  (9.2, '“ image super'),
#  (9.166666666666668, 'chemical language'),
#  (9.0, 'fair guiding principles'),
#  (9.0, 'driven automatic recogni'),
#  (9.0, 'decode 2dchemical diagrams'),
#  (9.0, 'applied physics reviewsreviewscitation'),
#  (9.0, '9454 – 9465'),
#  (9.0, '783 – 787'),
#  (9.0, '780 – 787'),
#  (9.0, '740 – 743'),
#  (9.0, '629 – 633'),
#  (9.0, '6077 – 6086'),
#  (9.0, '52 – 59'),
#  (9.0, '373 – 378'),
#  (9.0, '31 – 36'),
#  (9.0, '295 – 307'),
#  (9.0, '2818 – 2826'),
#  (9.0, '2048 – 2057'),
#  (9.0, '19461 – 19469'),
#  (9.0, '184 – 199'),
#  (9.0, '179 – 187'),
#  (9.0, '10313 – 10320'),
#  (9.0, '10214 – 10222'),
#  (8.666666666666666, '“ machine vision'),
#  (8.666666666666666, 'cole ,“ imagedataextractor'),
#  (8.5, '“ clide pro'),
#  (8.333333333333332, 'computer vision workshops'),
#  (8.214285714285715, '2018 ), pp'),
#  (8.214285714285715, '2018 ), pp'),
#  (8.214285714285715, '2015 ), pp'),
#  (8.214285714285715, '2014 ), pp'),
#  (8.142857142857142, '2020 ); doi'),
#  (8.047619047619047, '2017 ), pp'),
#  (8.047619047619047, '2016 ), pp'),
#  (8.0, 'rapid ): 1'),
#  (8.0, '8 – 12'),
#  (7.5, 'information system'),
#  (7.291666666666666, '2009 ). 137j'),
#  (7.166666666666666, '“ learning'),
#  (7.0, 'algorithmic interpretation'),
#  (7.0, '129m .- k'),
#  (6.866666666666666, 'visualattention ,”'),
#  (6.5, 'document analysis'),
#  (6.166666666666667, 'quantify data'),
#  (6.166666666666666, 'machine learning'),
#  (6.125, 'pattern recognition'),
#  (6.125, 'pattern recognition'),
#  (6.0, 'international conference'),
#  (5.75, 'structure'),
#  (5.7, 'image super'),
#  (5.5, '“ smiles'),
#  (5.5, '“ knowledgeextraction'),
#  (5.5, '“ kekule'),
#  (5.5, '“ inception'),
#  (5.5, '“ graphie'),
#  (5.5, '“ chemschematicresolver'),
#  (5.333333333333333, 'computer vision'),
#  (5.0, 'latest generation'),
#  (4.880952380952381, '.- j'),
#  (4.541666666666666, '2018 ).'),
#  (4.541666666666666, '2018 ).'),
#  (4.541666666666666, '2015 ).'),
#  (4.541666666666666, '2014 ).'),
#  (4.5, 'pattern anal'),
#  (4.375, '2017 ).'),
#  (4.375, '2017 ).'),
#  (4.375, '2016 ).'),
#  (4.375, '2016 ).'),
#  (4.291666666666666, '2009 ).'),
#  (4.291666666666666, '2009 ).'),
#  (4.291666666666666, '2009 ).'),
#  (4.184523809523809, '2020 ).'),
#  (4.184523809523809, '2020 ).'),
#  (4.184523809523809, '2020 ).'),
#  (4.184523809523809, '2020 ).'),
#  (4.184523809523809, '2020 ).'),
#  (4.184523809523809, '2020 ).'),
#  (4.041666666666666, 'matnavi ).'),
#  (4.041666666666666, '2019 ).'),
#  (4.041666666666666, '2019 ).'),
#  (4.041666666666666, '1992 ).'),
#  (4.041666666666666, '1988 ).'),
#  (4.041666666666666, '1962 ).'),
#  (4.0, 'unreasonable effectiveness'),
#  (4.0, 'quality control'),
#  (4.0, 'particle size'),
#  (4.0, 'onthe importance'),
#  (4.0, 'nlp models'),
#  (4.0, 'induced transformations'),
#  (4.0, 'humans second'),
#  (4.0, 'generalizable framework'),
#  (4.0, 'aip publishing'),
#  (3.625, 'recognition'),
#  (3.5, '“'),
#  (3.5, '“'),
#  (3.5, 'ocr'),
#  (3.2, 'image'),
#  (3.0, 'nims'),
#  (3.0, 'discovery'),
#  (3.0, '2'),
#  (2.7142857142857144, 'pp'),
#  (2.6666666666666665, 'vision'),
#  (2.5, 'intell'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.380952380952381, 'j'),
#  (2.3333333333333335, 'comput'),
#  (2.3333333333333335, 'comput'),
#  (2.3333333333333335, 'chem'),
#  (2.3333333333333335, 'chem'),
#  (2.3333333333333335, 'chem'),
#  (2.3333333333333335, 'chem'),
#  (2.3333333333333335, 'chem'),
#  (2.3333333333333335, 'chem'),
#  (2.3333333333333335, 'chem'),
#  (2.0, 'sci'),
#  (2.0, 'sci'),
#  (2.0, 'sci'),
#  (2.0, 'cole'),
#  (2.0, 'clide'),
#  (2.0, '12'),
#  (2.0, '1'),
#  (1.5555555555555556, 'inf'),
#  (1.5555555555555556, 'inf'),
#  (1.5555555555555556, 'inf'),
#  (1.5555555555555556, 'inf'),
#  (1.5555555555555556, 'inf'),
#  (1.5555555555555556, 'inf'),
#  (1.5555555555555556, 'inf'),
#  (1.5555555555555556, 'inf'),
#  (1.5, 'k'),
#  (1.5, 'k'),
#  (1.5, 'k'),
#  (1.0, 'z'),
#  (1.0, 'z'),
#  (1.0, 'yildirim'),
#  (1.0, 'xu'),
#  (1.0, 'xia'),
#  (1.0, 'x'),
#  (1.0, 'x'),
#  (1.0, 'wu'),
#  (1.0, 'work'),
#  (1.0, 'wojna'),
#  (1.0, 'williams'),
#  (1.0, 'weininger'),
#  (1.0, 'wall'),
#  (1.0, 'vlcek'),
#  (1.0, 'vasudevan'),
#  (1.0, 'vanhoucke'),
#  (1.0, 'valko'),
#  (1.0, 'v3'),
#  (1.0, 'v'),
#  (1.0, 'v'),
#  (1.0, 'v'),
#  (1.0, 'tran'),
#  (1.0, 'top'),
#  (1.0, 'toolkit'),
#  (1.0, 'tool'),
#  (1.0, 'tion'),
#  (1.0, 'theory8'),
#  (1.0, 'terrones'),
#  (1.0, 'tell'),
#  (1.0, 'tang'),
#  (1.0, 'tang'),
#  (1.0, 'szegedy'),
#  (1.0, 'syst'),
#  (1.0, 'syst'),
#  (1.0, 'springer'),
#  (1.0, 'smith'),
#  (1.0, 'singh'),
#  (1.0, 'shlens'),
#  (1.0, 'santus'),
#  (1.0, 'ribeiro'),
#  (1.0, 'rev'),
#  (1.0, 'ranzato'),
#  (1.0, 'r'),
#  (1.0, 'r'),
#  (1.0, 'r'),
#  (1.0, 'r'),
#  (1.0, 'r'),
#  (1.0, 'r'),
#  (1.0, 'qian'),
#  (1.0, 'proceedings'),
#  (1.0, 'proceedings'),
#  (1.0, 'phys'),
#  (1.0, 'pereira'),
#  (1.0, 'perea'),
#  (1.0, 'pan'),
#  (1.0, 'p'),
#  (1.0, 'p'),
#  (1.0, 'p'),
#  (1.0, 'overview'),
#  (1.0, 'osra'),
#  (1.0, 'org'),
#  (1.0, 'norvig'),
#  (1.0, 'nikolaev'),
#  (1.0, 'nicklaus'),
#  (1.0, 'nan'),
#  (1.0, 'n'),
#  (1.0, 'mukaddem'),
#  (1.0, 'morphology'),
#  (1.0, 'model'),
#  (1.0, 'model'),
#  (1.0, 'model'),
#  (1.0, 'model'),
#  (1.0, 'model'),
#  (1.0, 'methodology'),
#  (1.0, 'mcdaniel'),
#  (1.0, 'mayhew'),
#  (1.0, 'mater'),
#  (1.0, 'maksov'),
#  (1.0, 'mach'),
#  (1.0, 'loy'),
#  (1.0, 'loy'),
#  (1.0, 'lopez'),
#  (1.0, 'license'),
#  (1.0, 'large'),
#  (1.0, 'lample'),
#  (1.0, 'labels'),
#  (1.0, 'l'),
#  (1.0, 'l'),
#  (1.0, 'kim'),
#  (1.0, 'kim'),
#  (1.0, 'kearsey'),
#  (1.0, 'karande'),
#  (1.0, 'kaplan'),
#  (1.0, 'kalinin'),
#  (1.0, 'journal'),
#  (1.0, 'johnson'),
#  (1.0, 'jin'),
#  (1.0, 'ioffe'),
#  (1.0, 'introduction'),
#  (1.0, 'improving'),
#  (1.0, 'ieeeconference'),
#  (1.0, 'hu'),
#  (1.0, 'hooper'),
#  (1.0, 'han'),
#  (1.0, 'han'),
#  (1.0, 'halevy'),
#  (1.0, 'h'),
#  (1.0, 'h'),
#  (1.0, 'guo'),
#  (1.0, 'guestrin'),
#  (1.0, 'groups'),
#  (1.0, 'greenaway'),
#  (1.0, 'graph'),
#  (1.0, 'go'),
#  (1.0, 'g'),
#  (1.0, 'filippov'),
#  (1.0, 'f'),
#  (1.0, 'extract'),
#  (1.0, 'ekins'),
#  (1.0, 'e'),
#  (1.0, 'e'),
#  (1.0, 'e'),
#  (1.0, 'dong'),
#  (1.0, 'dong'),
#  (1.0, 'denoyer'),
#  (1.0, 'defect'),
#  (1.0, 'data5'),
#  (1.0, 'data3'),
#  (1.0, 'conneau'),
#  (1.0, 'computing'),
#  (1.0, 'computervision'),
#  (1.0, 'clark'),
#  (1.0, 'cheminf'),
#  (1.0, 'cent'),
#  (1.0, 'c19egou'),
#  (1.0, 'c'),
#  (1.0, 'c'),
#  (1.0, 'c'),
#  (1.0, 'c'),
#  (1.0, 'c'),
#  (1.0, 'c'),
#  (1.0, 'c'),
#  (1.0, 'briggs'),
#  (1.0, 'behavioraltesting'),
#  (1.0, 'beard'),
#  (1.0, 'beard'),
#  (1.0, 'basedframework'),
#  (1.0, 'barzilay'),
#  (1.0, 'balmuth'),
#  (1.0, 'b'),
#  (1.0, 'b'),
#  (1.0, 'b'),
#  (1.0, 'b'),
#  (1.0, 'b'),
#  (1.0, 'attention'),
#  (1.0, 'attend'),
#  (1.0, 'atool'),
#  (1.0, 'appl'),
#  (1.0, 'annotationprocess'),
#  (1.0, 'alston'),
#  (1.0, 'agement'),
#  (1.0, '93'),
#  (1.0, '9'),
#  (1.0, '7'),
#  (1.0, '7'),
#  (1.0, '60'),
#  (1.0, '60'),
#  (1.0, '60'),
#  (1.0, '5'),
#  (1.0, '5'),
#  (1.0, '49'),
#  (1.0, '49'),
#  (1.0, '4'),
#  (1.0, '38'),
#  (1.0, '3387'),
#  (1.0, '32'),
#  (1.0, '3'),
#  (1.0, '28'),
#  (1.0, '2492'),
#  (1.0, '24'),
#  (1.0, '2059'),
#  (1.0, '2005'),
#  (1.0, '19published'),
#  (1.0, '1810'),
#  (1.0, '180053'),
#  (1.0, '1710'),
#  (1.0, '160018'),
#  (1.0, '154a'),
#  (1.0, '153m'),
#  (1.0, '152r'),
#  (1.0, '151z'),
#  (1.0, '150p'),
#  (1.0, '149a'),
#  (1.0, '148j'),
#  (1.0, '147a'),
#  (1.0, '146seemits'),
#  (1.0, '145m'),
#  (1.0, '144a'),
#  (1.0, '143y'),
#  (1.0, '142k'),
#  (1.0, '141p'),
#  (1.0, '140d'),
#  (1.0, '139e'),
#  (1.0, '138i'),
#  (1.0, '136a'),
#  (1.0, '135j'),
#  (1.0, '134w'),
#  (1.0, '133e'),
#  (1.0, '132x'),
#  (1.0, '131c'),
#  (1.0, '130h'),
#  (1.0, '13083'),
#  (1.0, '128c'),
#  (1.0, '127c'),
#  (1.0, '126r'),
#  (1.0, '125k'),
#  (1.0, '124l'),
#  (1.0, '123a'),
#  (1.0, '1063'),
#  (1.0, '101553'),
#  (1.0, '10'),
#  (1.0, '10'),
#  (1.0, '041317'),
#  (1.0, '041317'),
#  (1.0, '04118'),
#  (1.0, '04087'),
#  (1.0, '00211067')]

# %%
corpus = "The invention relates to a book-keeping machine intended for the calculation and recording of new balances resulting from old balances of an account and the amounts received and paid out. A balance mechanism, which in known manner comprises two kinds of counting wheels, viz. adding and subtracting wheels, serves for the calculation of the new balances."

# %%
dp = pd.read_csv('papers.csv', encoding='unicode_escape')

# %%
dp
# Out:
#      paper_id                                              title  \
# 0           1  Ensemble Statistical and Heuristic Models for ...
# 1           2  Improving Spectral Learning by Using Multiple ...
# 2           3  Applying Swarm Ensemble Clustering Technique f...
# 3           4      Reducing the Effects of Detrimental Instances
# 4           5         Concept Drift Awareness in Twitter Streams
# ..        ...                                                ...
# 443       444  A Machine Learning Tool for Supporting Advance...
# 444       445  Advanced ECHMM-Based Machine Learning Tools fo...
# 445       446  A Cluster Analysis of Challenging Behaviors in...
# 446       447  Predicting Psychosis Using the Experience Samp...
# 447       448  Bayesian Nonparametric Clustering of Patients ...
#
#                                               keywords  \
# 0    statistical word alignment, ensemble learning,...
# 1    representation, spectral learning, discrete fo...
# 2    software defect prediction, particle swarm opt...
# 3           filtering, label noise, instance weighting
# 4    twitter, adaptation models, time-frequency ana...
# ..                                                 ...
# 443  machine-learning,unsupervised-learning,knowled...
# 444  workload characterization,hmm,cepstral coeffic...
# 445  cluster analysis,autism spectrum disorder,chal...
# 446  predicting psychosis,esm,mhealth,svm,gaussian ...
# 447  bayes methods,monte carlo methods,numerical si...
#
#                                               abstract  \
# 0    Statistical word alignment models need large a...
# 1    Spectral learning algorithms learn an unknown ...
# 2    Number of defects remaining in a system provid...
# 3    Not all instances in a data set are equally be...
# 4    Learning in non-stationary environments is not...
# ..                                                 ...
# 443  In the current era of big data, high volumes o...
# 444  We present a novel approach for accurate chara...
# 445  We apply cluster analysis to a sample of 2,116...
# 446  Smart phones have become ubiquitous in the rec...
# 447  Bayesian nonparametric (BNP) statistical techn...
#
#                                                session  year
# 0                                     Ensemble Methods  2014
# 1                                     Ensemble Methods  2014
# 2                                     Ensemble Methods  2014
# 3                                     Ensemble Methods  2014
# 4                                     Ensemble Methods  2014
# ..                                                 ...   ...
# 443                       Machine Learning on Big Data  2017
# 444                       Machine Learning on Big Data  2017
# 445  Machine Learning Applications in Psychiatric R...  2017
# 446  Machine Learning Applications in Psychiatric R...  2017
# 447  Machine Learning Applications in Psychiatric R...  2017
#
# [448 rows x 6 columns]

# %%
with open('papers.csv', 'r') as csvfile:
    csvtext = csvfile.readlines()

mylist = []
for line in csvtext:
    mylist.append(tuple(line.strip().split(', ')))
print(mylist)
# Out:
# [('paper_id,title,keywords,abstract,session,year',), ('1,Ensemble Statistical and Heuristic Models for Unsupervised Word Alignment,"statistical word alignment', 'ensemble learning', 'heuristic word alignment","Statistical word alignment models need large amount of training data while they are weak in small-size corpora. This paper proposes a new approach of unsupervised hybrid word alignment technique using ensemble learning method. This algorithm uses three base alignment models in several rounds to generate alignments. The ensemble algorithm uses a weighed scheme for resampling training data and a voting score to consider aggregated alignments. The underlying alignment algorithms used in this study include IBM Model 1', '2 and a heuristic method based on Dice measurement. Our experimental results show that by this approach', 'the alignment error rate could be improved by at least %15 for the base alignment models.",Ensemble Methods,2014'), ('2,Improving Spectral Learning by Using Multiple Representations,"representation', 'spectral learning', 'discrete fourier', 'basis selection', 'ensemble","Spectral learning algorithms learn an unknown function by learning a spectral (e.g.', 'Fourier) representation of the function. However', 'there are many possible spectral representations', 'none of which will be best in all situations. Consequently', 'it seems natural to consider how a spectral learner could make use of multiple representations when learning. This paper proposes and compares three approaches to learning from multiple spectral representations. Empirical results suggest that an ensemble approach to multi-spectrum learning', 'in which spectral models are learned independently in each of a set of candidate representations and then combined in a majority-vote ensemble', 'works best in practice.",Ensemble Methods,2014'), ('3,Applying Swarm Ensemble Clustering Technique for Fault Prediction Using Software Metrics,"software defect prediction', 'particle swarm optimization', 'cluster data', 'ensemble clustering","Number of defects remaining in a system provides an insight into the quality of the system. Defect detection systems predict defects by using software metrics and data mining techniques. Clustering analysis is adopted to build the software defect prediction models. Cluster ensembles have emerged as a prominent method for improving robustness', 'stability and accuracy of clustering solutions. The clustering ensembles combine multiple partitions generated by different clustering algorithms into a single clustering solution. In this paper', 'the clustering ensemble using Particle Swarm Optimization algorithm (PSO) solution is proposed to improve the predict quality. An empirical study shows that the PSO can be a good choice to build defect prediction software  models.",Ensemble Methods,2014'), ('4,Reducing the Effects of Detrimental Instances,"filtering', 'label noise', 'instance weighting","Not all instances in a data set are equally beneficial for inducing a model of the data. Some instances (such as outliers or noise) can be detrimental. However', 'at least initially', 'the instances in a data set are generally considered equally in machine learning algorithms. Many current approaches for handling noisy and detrimental instances make a binary decision about whether an instance is detrimental or not. In this paper', 'we 1) extend this paradigm by weighting the instances on a continuous scale and 2) present a methodology for measuring how detrimental an instance may be for inducing a model of the data. We call our method of identifying and weighting detrimental instances reduced detrimental instance learning (RDIL). We examine RIDL on a set of 54 data sets and 5 learning algorithms and compare RIDL with other weighting and filtering approaches. RDIL is especially useful for learning algorithms where every instance can affect the classification boundary and the training instances are considered individually', 'such as mul ...

# %%
text = str(mylist)

# %%
r.preprocess(text)
r.extract_keywords_from_text(text)
r.get_ranked_phrases()
# Out:
# ['arctic sea ice extent forecasting using support vector regression ," arctic sea ice \',',
#  'lecture vdeo indexing using boosted margin maximizing neural networks ," video indexing',
#  'extensive empirical study utilizing four bootstrap approaches within bagging framework using three feature rankers along',
#  'next generation wireless networks using coloured petri nets ," next generation wireless networks',
#  'topic novelty detection using infinite variational inverted dirichlet mixture models ," inverted dirichlet',
#  'sunspot number using minimum error entropy cost based kernel adaptive filters ," kernel methods',
#  'shot periodic activity recognition using convolutional neural networks ," human activity recognition \',',
#  'uncertainty quantified matrix completion using bayesian hierarchical matrix factorization ," bayesian analysis \',',
#  'based inferential control system using kernel principle component analysis ," control systems \',',
#  'audio signal reconstruction using cartesian genetic programming evolved artificial neural network',
#  'linear estimation algorithm called cartesian genetic programming evolved artificial neural network',
#  'direct multiclass boosting using base classifiers \\\' posterior probabilities estimates ," machine learning',
#  'action bank features using convolutional neural networks ," human action recognition \',',
#  'intensive care units via orthogonal matching pursuit ," logistic regression \',',
#  'relationships found reveal semantic paths linking two concepts across multiple text units',
#  'scene matching "," optical images display drastically reduced visibility due',
#  'acoustic events using masked conditional neural networks ," restricted boltzmann machine',
#  'ssh brute force attacks using aggregated netflow data ," intrusion detection',
#  'smart grid using cgp evolved artificial neural networks ," cgpann',
#  'residential house using artificial neural networks ," artificial neural network',
#  'variable neural network forecasting using two stage feature selection ," forecasting \',',
#  'forward looking sonar scene matching using deep learning ," deep learning',
#  'infrared colorization using deep convolutional neural networks ," neural networks',
#  'mocap information using convolution neural networks ," convolutional neural networks',
#  'major classical face recognition techniques ," blind source seperation \',',
#  'automatically refining manually built bayesian networks ," medical informatics \',',
#  'applications workshop ", 2015 \'), (\' 186 ," measuring level',
#  'neuro evolutionary cartesian genetic programming evolved artificial neural network',
#  'detecting credit card fraud using periodic features ," fraud detection',
#  'intelligent bus stop identification using smartphone sensors ," intelligent systems',
#  'second model called "" exponentially weighted ensemble "" combines individual regressors',
#  'lifelong machine learning systems ," lifelong machine learning \',',
#  'computed tomography via optimum path snakes ," active contour method',
#  'machine learning based cyber forensic biometric systems ," cyber forensic',
#  '2017 \'), (\' 409 ," cybersecurity automated information extraction techniques',
#  'thin film flow problem using stochastic solver like genetic algorithm',
#  'power grid failure using neural network learning ," power grid analysis',
#  'first ensemble method called "" recent leader "" picks',
#  'heuristic word alignment "," statistical word alignment models need large amount',
#  'morphologically rich languages using word embeddings ," czech ner \',',
#  'deep learning "," increasingly large document collections require improved information processing methods',
#  'improved wind power forecasting using combination methods ," wind power forecasting',
#  'raw accelerometer data using deep neural networks ," activity recognition',
#  'stock trend prediction via narx neural network ," trend prediction',
#  'document knowledge discovery using semantic concept topic model ," knowledge discovery',
#  'component analysis via bit flipping ," anomaly detection',
#  'medical simulation data using fisher vector representation ," speaker identification',
#  'smartphone indoor localization via deep learning ," indoor localization',
#  'semantic indexing based automatic text summarization ," text summarization',
#  'attribute assisted interpretation confidence classification using machine learning ," self',
#  'integrated circuits "," popular online publishers produce huge amount',
#  'privacy preserving record linkage using metasoundex algorithm ," data mining',
#  'fault prediction using software metrics ," software defect prediction \',',
#  'robust vehicle tracking using perceptual hashing algorithm ," feature extraction',
#  'transcription factor binding site analysis ," hidden markov models',
#  'solar radiation prediction improvement using weather forecasts ," machine learning',
#  'rotation invariant fingerprint matching algorithm using adjustment factor ," minutiae',
#  'compatibility based intuitionistic fuzzy rough sets ," granular computing',
#  'temporally precise control using machine learning ," robot control',
#  'plots produced indicate distinct stylistic differences betweens singers',
#  'intelligent crude oil price forecaster ," gaussian process \',',
#  'magnetic resonance imaging provide computer aided diagnosis using automated methods',
#  'personalized multidimensional news update summarization system ," dh',
#  'investigating eating behaviours using topic models ," topic models',
#  'bird call identification using dynamic kernel based support vector machines',
#  "multiple deep convolutional neural networks including residual networks ',",
#  'learning robust video synchronization without annotations ," deep learning',
#  'unsupervised word alignment ," statistical word alignment \',',
#  'domain ontology induction using word embeddings ," language modeling',
#  'human motion trajectory analysis based video summarization ," summarization',
#  'occluded objects using fast recurrent processing ," recurrent processing',
#  'automated patent classification using word embedding ," automated classification',
#  'weighted labels using learning classifier systems ," learning classifier systems',
#  'prostate cancer detection problem using magnetic resonance imaging data',
#  'facial expression recognition using deep convolutional neural networks',
#  'parallelizing topologically indicative mapping exemplars ," self',
#  'extensive credit default swap time series database available online',
#  'unsupervised hybrid word alignment technique using ensemble learning method',
#  'deep neural network based speech enhancement ," speech enhancement',
#  'offline highway traffic flow prediction ," traffic prediction \',',
#  'smart device user recognition gestures ," demographic group prediction',
#  'remedial action classification based approach ," educational data mining',
#  'esr "," automatic feature extraction using neural networks',
#  'american sign language recognition using leap motion sensor',
#  'conformalized kernel ridge regression ," kernel ridge regression',
#  'heart disease "," common stream mining tasks include classification \',',
#  'switched markov decision processes ," markov decision processes \',',
#  'spatiotemporal deep learning approaches outperform conventional machine learning approaches',
#  'carbon fiber fault detection ," online process monitoring',
#  'convolutional neural network accuracy ," convolutional neural network',
#  "go beyond traditional approaches like principal component analysis ',",
#  'impute missing gene expression data ," missing data',
#  'activity recognition using graphical features ," smart environment \',',
#  'performing hotspot analysis using localized kernel density estimation optimized',
#  'false positives without losing already selected true positives',
#  'achieving privacy preserving record linkage using phonetic encoding',
#  'deep learning based car damage classification ," automobiles',
#  'computer generated forces inhabiting air combat training simulations',
#  'track generic objects using online convolutional neural networks',
#  'relevant trading signal information using foreign exchange market data',
#  'language models outperforms methods using models like lsi',
#  'big data processing ", 2015 \'), (\' 215',
#  'big data processing ", 2015 \'), (\' 214',
#  'big data processing ", 2015 \'), (\' 213',
#  'big data processing ", 2015 \'), (\' 212',
#  'clustering big mobile social data ," big data analytics',
#  'physical models ," thin film flow equation',
#  'stochastic gradient descent ," traffic flow prediciton',
#  'convolutional neural networks ," convolutional neural networks',
#  'email recommendation response rates harnessing individual activity levels',
#  'facial images using machine learning ," adenoviral conjunctivitis',
#  'ndt "," carbon fiber reinforced plastics',
#  'scene classification using support vector machines ," kernel',
#  'wireless sensor networks ," wireless sensor networks',
#  'semantic slot labelling ," natural language processing \',',
#  'based human activity recognition ," multiple kernel learning',
#  'deep neural networks could generalize across different application domains',
#  'learning infinite spike train ," spiking neural network',
#  'statistical learning via manifold learning ," statistical learning',
#  'attackers also target governmental websites using ddos attacks',
#  'supervised learning via coherent point drifting ," semi',
#  'retinal image quality assessment "," weakly supervised learning',
#  'many machine learning regression models including support vector regression',
#  'level test case prioritization using machine learning ," system',
#  "new architecture automatically balances synapses modulation ',",
#  'building radiation hybrid maps ," radiation hybrid mapping',
#  '2015 \'), (\' 156 ," statistical downscaling',
#  'variational bayes deployed using approximate conjugate priors',
#  'many neural network based abdominal organ segmentation approaches',
#  'novel personalized news summarization system utilizing olap',
#  'heterogeneous networks ," neural network based machine learning',
#  'uwb radar using machine learning ," obstructive apnea',
#  'facial expression recognition "," facial expression recognition',
#  'stage cascaded classification system using wavelet analysis coupled',
#  'reads printed words contained within images .""',
#  'also conduct comparison experiments using three conventional machine learning approaches',
#  '412 pregnant women including 1874 clinical follow',
#  'sparse temporal difference learning via alternating direction method',
#  "mostly transferable across similar network topologies ',",
#  'synchronous stochastic gradient descent ," distributed sgd',
#  'vulnerable software components via ensemble learning ," vulnerability',
#  'summary sentence classification using stylometry ," summarization',
#  'segment multilingual message without utilizing machine translation',
#  'based adaptive web scraper ," web scraping',
#  'big data processing ", 2015 \'), (\' 216',
#  '2016 \'), (\' 336 ," epilepsy \',',
#  'minimally invasive attack mitigation via detection isolation',
#  'hedonic housing regression model ," real estate prediction',
#  'summer minimum arctic sea ice extent',
#  'applications workshop ", 2015 \'), (\' 196',
#  'applications workshop ", 2015 \'), (\' 195',
#  'applications workshop ", 2015 \'), (\' 194',
#  'applications workshop ", 2015 \'), (\' 185',
#  'applications workshop ", 2015 \'), (\' 184',
#  'applications workshop ", 2015 \'), (\' 183',
#  'applications workshop ", 2015 \'), (\' 174',
#  'applications workshop ", 2015 \'), (\' 173',
#  'applications workshop ", 2015 \'), (\' 172',
#  'applications workshop ", 2015 \'), (\' 171',
#  'feature selection "," home appliance monitoring provides useful information',
#  'big data processing ", 2015 \'), (\' 211',
#  'enhanceing collaborative learning ," collaborative learning \',',
#  'stochastic gradient descent "," advanced traffic management systems',
#  'medical image classification via svm using lbp features',
#  'minimum description length principle ," machine learning',
#  'smart cities ," license plate recognition system',
#  "previous alignment methods similarly consider weather conditions ',",
#  '2014 \'), (\' 35 ," variational inference',
#  'wifi csi data mining "," human activity recognition',
#  'modified traclus clustering ," traclus clustering \',',
#  'cancer drugs "" neoadjuvant docetaxel "".',
#  'nearest neighbor search ?," nearest neighbor search \',',
#  'artificial neural network based abdominal organ segmentations',
#  'memory distributed algorithms utilizing supervised machine learning techniques',
#  'visual inspection using evolving classifiers ," expected change',
#  'markov decision process "," wireless content delivery networks',
#  'text using machine learning ," integrative complexity \',',
#  'buildings "," buildings consume almost 40 \\\\%',
#  'deep neural networks involves two learning phases',
#  'advanced radioactive threat detection ," machine learning',
#  'gradient approximation via cd learning usually becomes far',
#  'sensor devices monitoring human activity generates voluminous amount',
#  'sql injection attack ," sql injection attack',
#  'neural network approach ," artificial neural network',
#  'evolving fuzzy image thresholding ," evolving fuzzy systems',
#  'facial expression recognition using kinect depth sensor',
#  'deep convolutional neural networks ," activation function',
#  'recognizing negative images ," convolutional neural networks',
#  'admission application essays ," educational data mining',
#  'arid continental climate ," machine learning algorithms',
#  'randomized controlled trial comparing individual meaning centered psychotherapy',
#  'high frequency trading strategies ," sociology \',',
#  'personalized audio equalization ," personalized item \',',
#  'simple clustering based methods using distributed word vectors',
#  'wireless epileptic seizure detection ," eeg signals',
#  'first stage discriminates normal car following regimes',
#  'memory brand perception tracking framework ," big data',
#  'unsupervised machine learning "," online forums provide peer',
#  'functional time series modeling ," functional time series',
#  'local node similarity measures ," social network analysis',
#  'student examination achievement ," educational data mining',
#  'knn phoneme prediction scheme using speaker ranking vector',
#  'different machine learning classifiers namely support vector machine',
#  'computational software using machine learning ," resultant',
#  'optimize virtual world simulator performance ," vertical scaling',
#  'glass "," image based vehicle insurance processing',
#  'coordinate descent fuzzy twin support vector machine',
#  'decentralized resource allocation game ," resource management',
#  'second stage classifies normal car following regimes',
#  'intracellular microtubule networks ," deep learning',
#  'counter time series data ," storage system',
#  'neural network control ," neural network \',',
#  'doubles pong game ," artificial intelligence',
#  'home appliance energy disaggregation using low frequency data',
#  'time series classification ," time series analysis \',',
#  'lcm "," nearest neighbor based nonparametric regression',
#  'eliminating useless dimensions ," reinforcement learning \',',
#  'gaussian mixture model cluster forest ," cluster forest',
#  'mining complex events using frequent sequence pattern mining',
#  "several slightly smaller size data replications ',",
#  'brains ’ networked control system "," brain',
#  'hematopoietic stem cell transplant often requires physicians',
#  "novel user representation based human behavior prediction model ',",
#  'distributed conformal anomaly detection ," conformal prediction',
#  'called "" load spectrum "" data resulting',
#  'testing kmeans -- based representation learning achieves 97',
#  'collaborative filtering recommender systems ," recommender systems',
#  'scale predictands using multiple linear regression models',
#  'code using machine learning ," algorithm recognition',
#  'robust recurrent kernel online learning ," real',
#  '2015 \'), (\' 232 ," prediction',
#  'load forecasting ," artificial neural networks',
#  'deep regression model utilizing cascaded sparse autoencoders',
#  'based multimedia timeline analysis ," sequential pattern',
#  "supervised learning expectedly outperforms unsupervised learning ',",
#  'anytime nearest neighbor classification ," anytime algorithm \',',
#  'machine learning "," social media captures voice',
#  'automated database schema matching ," computational modeling',
#  'simulation support .," machine learning algorithms \',',
#  'active contour method called optimum path snakes',
#  'cooperative ensemble training strategy using two optimization algorithms',
#  'heart rate "," high false alarm rates',
#  'chronically record hippocampal evoked potentials elicited',
#  'serendipitous discovery "," deceptive fitness landscapes',
#  "art credit card fraud detection models ',",
#  'machine learning techniques ," indoor user movement',
#  'busted real estate market spanning 11 years',
#  'deep neural networks ," neural networks',
#  'computer generated forces "," machine learning techniques',
#  'narx neural network "," evolving networks \',',
#  'simulator administrators often make arbitrary resource allocations',
#  'boosted deep convolutional neural network system',
#  'manually produced ssh failed login data showed',
#  'effective user authentications using keystroke dynamics based',
#  'bounded sectional curvature ," primal dual algorithm',
#  'image recognition ," convolutional neural networks',
#  'line signature verification using symbolic aggregate approximation',
#  'supervised music chord recognition ," music \',',
#  'data mining "," collective latent dirichlet allocation',
#  'big healthcare data ," mining big data',
#  'two base classifiers across 15 imbalanced bioinformatics datasets',
#  'newly developed nottingham prognostic index plus',
#  'mobile stores ," mobile store security \',',
#  'ecg biometric identification using wavelet analysis coupled',
#  '2017 \'), (\' 391 ," eyequal',
#  'relevant spiking neural network learning algorithms based',
#  'sofm called decaying potential fields neural network',
#  'machine learning feature vectors ," kernel method',
#  'complex big data applications ," workload characterization',
#  'machine learning "," wireless body area networks',
#  'transfer learning techniques successfully improve keyword spotting performance',
#  'xgboost "," modern railway networks include thousands',
#  'using joint probability distribution ," bayesian network',
#  'improved birdsong analysis ," syllable segmentation',
#  'based discriminative learning frameworks ," mixture models',
#  'measuring brand perception using lengthy surveys',
#  'value child support cases ," child support',
#  'software defined networking ," software defined networks',
#  'understading image restoration convolutional neural networks',
#  'adaptive openmp task scheduling using runtime apis',
#  'human behavior prediction ," human behavior prediction',
#  'developing personalized treatment ," reinforcement learning \',',
#  'cloud computing "," license plate recognition system',
#  'horizon line detection ," horizon line detection',
#  'prostate cancer detection ," multi instance classification',
#  'temporal hedonic house regression model ," k',
#  'stochastic gradient descent deploys online forecasting',
#  'using different algorithm ," classification algorithms \',',
#  'initial results using varying missing data proportions',
#  'english fa cup final 2012 played',
#  'unsupervised learning "," many statistical learning tasks deal',
#  'game theoretic intuitionistic fuzzy rough sets',
#  'game theoretic intuitionistic fuzzy rough sets',
#  'circumvent search engines aiming good visibility',
#  'expectation maximization "," wireless eeg monitoring systems',
#  'time series prediction ," time series prediction',
#  'hedonic housing regression model using mutual information',
#  "year historical dataset including daily average temperature ',",
#  'sourced segmentations may sometimes produce unwanted noise',
#  'hematopoietic stem cell transplant using cost',
#  'electricity retail markets ," electricity retail markets',
#  'text mining "," web site privacy policies',
#  'use case point estimation method ," effort prediction',
#  'neural networks "," recurrent neural networks',
#  'clinical depressive disorders ," bayesian networks',
#  'heart disease use case ," weka \',',
#  'footprint keyword spotting ," transfer learning',
#  'driven optimal control ," learning convex function',
#  'combining classical univariate supervised feature selection techniques',
#  'credit scoring ," cost sensitive classification \',',
#  'training tweet sentiment classifiers ," sentiment analysis',
#  'student retention pattern prediction employing linguistic features extracted',
#  "learned feature maps via deconvolutional networks ',",
#  'theoretical perspective ," large scale network flow',
#  "new hybrid approach addressing feature selection ',",
#  'american sign language recognition system using',
#  'training speed "," training artificial neural networks',
#  'concern typically follows large scale power grid failures',
#  'budgeted learning algorithm demonstrated excellent performance across',
#  'new multiclass boosting algorithm called adaboost',
#  "approach identifies local bins per itemset ',",
#  'clustering ensemble using particle swarm optimization algorithm',
#  'blood pressure ," varying coefficient model \',',
#  'learned speech kernels ," acoustic feature learning',
#  'noisy data ," nonnegative matrix factorization',
#  'diagnosing certain eye diseases using image processing',
#  "modern emerging social systems like twitter ',",
#  'multiple classifier systems ," multiple classifier systems',
#  'particular data points called margin support vectors',
#  'incremental dynamic search solver ," timetabling',
#  'health social networks "," human behavior prediction',
#  'improve sentiment analysis ," feature discovery \',',
#  "bih normal sinus rhythm database ',",
#  'neural network based pid parameter selection control',
#  'high dimension data clustering ," feature selection',
#  'music ", 2014 \'), (\' 66',
#  'music ", 2014 \'), (\' 64',
#  'music ", 2014 \'), (\' 62',
#  'joint inference "," markov logic networks \',',
#  'proposed hybrid technique could identify potentially vulnerable classes',
#  'speech separation ," nonnegative matrix factorization',
#  'artificial neural networks "," deep architectures',
#  'based approach ," abnormal event detection \',',
#  'segment perfusion magnetic resonance liver images',
#  'recognizing musical artist influence ," music',
#  'rice continuous genome wide association studies given',
#  "neural networks based machine learning approach ',",
#  "credit card fraud detection model ',",
#  'accurate learning ," recurrent neural network',
#  'generate brief summaries delivering news updates',
#  'based deep learning license plate recognition',
#  'air combat behavior ," reinforcement learning',
#  'based folded data ," image classification',
#  'medical image analysis "," every segmentation algorithm',
#  'neural network inference ," machine learning',
#  'parallelizing synchronous stochastic gradient descent',
#  'markov logic networks ," opinion extraction',
#  'different image clutter metrics using multivariate analyses',
#  'high acceptance rates ," pull request',
#  'fast cloud data retrieval ," distributed computing',
#  'neural network based reference modified pid control',
#  'event coreference resolution ," event coreference',
#  'group affinity trends ," recommendation emails',
#  'method usually assigns penalty uniformly distributed',
#  'mmse attribute estimators using image classifiers',
#  'better drug development strategy using partial knowledge',
#  'two sided preferences ," recommender systems \',',
#  'strategy learning "," bandit based optimisation schemes',
#  'force plate ," force plate \',',
#  '"" secondary "" selection process \',',
#  'machine learning techniques ," machine learning',
#  'seller lists dominate deployed recommendation engines',
#  'bipartite ranking problem ," bipartite ranking problem',
#  'neural conditional random fields ," hybrid',
#  'data streams ," support vector machines',
#  'deep learning algorithm computed using bare',
#  'smart meter data ," data mining',
#  'led based indoor localization system using k',
#  'proposed contour representation extracts repetitive temporal patterns',
#  "large european card processing company ',",
#  'arctic sea ice extent',
#  'arctic sea ice extent',
#  'numenta anomaly benchmark ," anomaly detection',
#  'negative images "," convolutional neural networks',
#  'machine learning based cyber forensic system',
#  'wind turbine diagnostics ," feature selection',
#  'ip model "," wireless sensor networks',
#  'traffic flow prediction ," metric learning',
#  "known algorithms ucb1 ', '? greedy",
#  'machine learning algorithms ," big data',
#  'biometrics "," efficient keystroke authentication systems',
#  'hybridelectric vehicle fleet ," vegetation',
#  "new efficient form using mobile apps ',",
#  'thin film flow equation arising',
#  'pattern mining based network dependency analysis algorithm',
#  "computer vision using machine learning method ',",
#  'bayesian classification "," recently emerging software applications',
#  'based programming models adopt different scheduling strategies',
#  'small training sets ," error analysis \',',
#  'crisis management using fuzzy discrete event system',
#  'enable fast data retrieval across multiple records',
#  'ch ), secure data aggregation model',
#  'machine learning models ," autoregressive processes',
#  'accelerated global optimisation ," global optimization',
#  'automatic dbms diagnosis ," anomaly detection',
#  'latent semantic indexing "," ontology \',',
#  'single instance using convolutional neural networks',
#  'dnn features ," deep neural networks',
#  'knowledge graph completion ," representation learning',
#  'biometric authentication systems ," machine learning',
#  'using multiple representations ," representation \',',
#  'two widely used robot platforms show significant actuation',
#  'predict student performance ," linear regression \',',
#  'detection using smo ," computer crime',
#  'combine exact efsm inference algorithms ~(',
#  'insolation period "," solar power penetration',
#  'phoneme prediction ," speech recognition \',',
#  'proposed dip approach successfully detects eye infections',
#  'competent deal teams design competitive service solutions',
#  'frequency response analysis fra ," transformer',
#  "well known first programming language c ++',",
#  'machine learning based lesion segmentation methods',
#  'power systems "," power loss minimization plays',
#  '2015 \'), (\' 206 ,"',
#  'autism spectrum disorder ," cluster analysis',
#  'hierarchical clustering analysis ," hierarchical clustering',
#  'contour representations "," temporal contour shapes',
#  'real credit card fraud dataset provided',
#  'neural networks ," neural networks',
#  "using different communication modalities including speech ',",
#  'hourly solar irradiance forecasting hybrid models',
#  'filer response time prediction using adaptively',
#  'housing market spanning 11 years using',
#  'defense mechanisms includes automated turing tests',
#  'human activity recognition ," accelerometers',
#  'generated traffic affects cache performance similarly',
#  'time series classification "," time series classification',
#  'sms text messages ," author classification',
#  'isolates potentially contagious patients correctly 93',
#  'two time series approaches namely naive method',
#  'surface strings without assuming predefined knowledge',
#  'unsupervised machine learning algorithm successfully tended',
#  'runtime analysis ," runtime analysis \',',
#  'widely investigated using different methods including probabilistic',
#  'discrete event systems ," adaptive approaches',
#  'machine learning classifiers ," smart energy',
#  'scale hierarchical classification ," hierarchical classification',
#  'secure biometric system components ," biometric',
#  'clustering nmf results across bootstrap resamples',
#  "patterns across action bank features ',",
#  'statistical learning ," statistical learning \',',
#  'machine learning investigation ," linear regression',
#  'architecture outperforms previous deep learning methods implemented',
#  'fire neurons ," machine learning \',',
#  'based topic models ," statistical learning',
#  'present spike event based weight update strategy',
#  'sequential pattern based temporal contour representations',
#  'artificial intelligence "," modern automobiles',
#  "game data -- including sports games ',",
#  "arctic sea ice ',",
#  'nonword repetition test ," automatic scoring',
#  'speech intelligibility "," deep neural networks',
#  'social networks using data mining techniques',
#  'predictable feature analysis ," data analysis',
#  'dbpedia ontology "," topic models \',',
#  'cases simple personalized recommenders achieve higher ranking',
#  'artificial neural network ," grid',
#  'music ", 2014 \'), (\' 63',
#  'arctic sea ice coverage',
#  'estimated using support vector machine learning',
#  "present three novel cyber entity extractors ',",
#  'big data "," using automated methods',
#  'brain mr images ," image segmentation',
#  'supervised learning ," active learning \',',
#  'photovoltaic energy prediction ," pv system',
#  'online privacy policies ," privacy policy',
#  'api mashups ," ap imashups',
#  'infinitely delayed labels ," data stream',
#  'many effective time series data mining algorithms',
#  'computational modeling "," solar irradiance forecasting',
#  'new algorithm named cyclic contrastive divergence',
#  'proposed framework using kheperaiii mobile robot',
#  'kmeans -- based unsupervised feature learning',
#  'classified using multinomial logistic regression fueled',
#  'synthetizing artificial defects ," inspection',
#  'music ", 2014 \'), (\' 65',
#  "× k weight matrix w ',",
#  'novel coordinate descent fuzzy twin svm',
#  'modelled using modern machine learning methods',
#  'modern activity recognition systems also require',
#  'sufficiently large publicly available annotated corpus',
#  'partially linear models ," feature selection',
#  'econometric concept using machine learning algorithms',
#  'genetic algorithm ", renewable energy sources provide',
#  'training "," standard symbolic aggregation approximation',
#  'oriented software ," object oriented software',
#  'length time series motifs ," grammar',
#  'kegg signalling pathways ," drug',
#  "potential random effects across multiple days ',",
#  'based temporal clustering ," kernel k',
#  'objective temporal difference afterstate algorithm outperforms',
#  'information theoretic learning "," several algorithms',
#  'interpretable prediction ," naive bayes classifier',
#  'contextual similarity measure ," collaborative recommendation',
#  'big data applications ," fault detection',
#  'ridge regression classifier "," phenotype prediction',
#  'advise students regarding likely success outcomes early',
#  'simple yet easily accessible android mobile application',
#  'convolutional neural networks ," cnn',
#  'improve training speed ," instance selection \',',
#  '106 subjects distributed across two sets',
#  'dense patterns ," time series clustering',
#  'neural network based machine learning scheme',
#  "still allows us outperform competing approaches ',",
#  'machine learning classifiers produce good overall accuracy',
#  'based reinforcement learning "," layered learning',
#  'based speech enhancement systems remains less',
#  'entire network using transductive learning algorithms',
#  'turkish universities ," urap rankings \',',
#  'require submetering high resolution power signals',
#  'defined networking cybersecurity applications ," software',
#  'product networks ," sum product networks',
#  'applied combination methods give lower nmae rates',
#  'neurofuzzy system ," target detection \',',
#  'temporal hedonic house pricing model without',
#  'software security ," software architecture \',',
#  "incremental learning system using artificial ',",
#  'traditional machine learning "," transfer learning',
#  'dynamic kernel based support vector machines',
#  'email recommendations add two critical additional dimensions',
#  'scientific collaboration network ," recommender systems',
#  'four major classical face recognition techniques',
#  'evolutionary algorithms "," consider optimization problems \',',
#  "method outperforms standard icu score systems ',",
#  'informed gaps ," complex event programming',
#  'revision operator called noise reduction operator',
#  'adaptation algorithm learns speaker similarity scores based',
#  "forecast solar irradiance one day ahead ',",
#  "early detect potential fetal growth problems ',",
#  'genetic algorithm based partitioning clustering program developed',
#  'movie namely "" profit ""',
#  'protein conformation motion modeling using sep',
#  'large text corpora ," text analysis',
#  'genetic algorithm "," kernel density estimation',
#  'hotspot policing ," crime prediction',
#  'positive examples ," information need modeling \',',
#  'top ranked support vector regression snps gives',
#  'sn ), wireless sensor network',
#  'activity awareness ," activity recognition',
#  'domain class imbalance ," transfer learning',
#  'domain class imbalance ," transfer learning',
#  'hard drive failure prediction methods using',
#  '2014 \'), (\' 12 ,"',
#  'neural network based handover management scheme',
#  'applications ", 2014 \'), (\' 91',
#  'deep networks ," deep learning',
#  'bayesian nonparametric inverse reinforcement learning technique',
#  'monte carlo "," smart phones',
#  'renewable energy applications ," predictive models',
#  'algorithm uses three base alignment models',
#  'neural network based handover management strategy',
#  'exponential regression "," variational inference \',',
#  'smart cities "," power grid failures',
#  'multilayer network "," supervised learning methods',
#  'orphan node prediction "," hierarchical classification',
#  'way anova "," automatic summarization \',',
#  'objective optimization ," interactive evolutionary computation',
#  'identifying nontechnical power loss via spatial',
#  'applications ", 2014 \'), (\' 92',
#  'lecture video indexing using',
#  'network inversion ," deep learning',
#  'algorithms "," machine learning algorithms \',',
#  'machine learning ," adaptive scheduling',
#  'neuroimaging data ," deep learning',
#  'maintained software projects ," software engineering',
#  'load spectrum data achieves promising classification performance',
#  'large data ," frequent set mining',
#  'auxiliary objectives ," parameter control \',',
#  'ngs data ," next generation sequence',
#  'machine learning "," software defined networking',
#  'concurrent learning agents using deep q',
#  'cameras "," deep neural networks',
#  'template matching "," speech recognition systems',
#  'go beyond market microstructure theory',
#  '3 × 4 × 4 m3',
#  'wireless sensor networks ," availability',
#  'proposed approach effectively exposes inpainting forgery',
#  'temporal link prediction using time series',
#  'student dropout profiles ," extraction patterns',
#  'network attacks "," intrusion detection systems',
#  'class fingerprints collected using mobile phones',
#  'constrained embedded devices ," anomaly prediction',
#  "continuous data via stacked autoencoders ',",
#  'many predictive analyses combined dimension reduction techniques',
#  'implicitly restarted lanczos bidiagonalization algorithm',
#  "layered learning heavily favors plasticity ',",
#  'fully parallelized mapping architecture based loosely',
#  'weighting detrimental instances reduced detrimental instance learning',
#  'improving hsdpa traffic forecasting using ensemble',
#  'intrusion detection ," intrusion detection',
#  'induction motors "," machine learning techniques',
#  'instant messages ," topic detection \',',
#  'automatic bitcoin address clustering ," bitcoin',
#  '"" secondary "" decision process',
#  'online anomaly intrusion detection system based',
#  'decorrelated approximators ," approximation algorithms',
#  'supervised machine learning based surface inspection',
#  'support vector machines "," good results',
#  "established narx neural network model ',",
#  'local predictive modeling ," predictive models',
#  'deep transductive nonnegative matrix factorization',
#  "performed using 55 data sets ',",
#  'distributed simulation "," virtual world simulation',
#  'information using convolutional neural networks',
#  'speaker adaptation using speaker similarity score',
#  'applications ", 2014 \'), (\' 93',
#  'multilayer feedforward spiking neural network',
#  'previously used metaheuristic ., machine learning',
#  'image forgery detection "," inpainting \',',
#  'guide classifiers including support vector machines',
#  'noise ," google cloud vision api',
#  'applications ", 2014 \'), (\' 94',
#  'supervised machine learning "," regression testing',
#  'voice discrimination ," features selection \',',
#  'constraint programming "," complex event processing',
#  'two stage markov regime switching model',
#  "difficult 2v2 scenarios transfer also occurs ',",
#  'deep neural networks ," bio',
#  'several machine learning algorithms like svm',
#  'lung image database consortium dataset ",',
#  'attribute assisted classification deriving estimates',
#  'problem specific manner using differential equations',
#  'achieve less power consumption without compromising',
#  "using two publicly available datasets ',",
#  'playing character ," neural networks',
#  'image restoration convolutional neural networks',
#  "crude oil price forecasting ',",
#  'deep reinforcement learning ," correlation',
#  'frequent sequential pattern mining algorithm suitable',
#  'comparative study ," high voltage feeder',
#  'pitch system "," wind turbine operation',
#  'transductive learning ," networks \',',
#  'probabilistic model called gaussian mixture model',
#  'series observations ," dynamical systems',
#  'dependent ssvep identification using gmm training',
#  'birdsong analysis based species recognition',
#  'paper aims toward achieving seamless connectivity',
#  'machine learning techniques ," biometric',
#  "consecutive frames using kalman filter ',",
#  'two stage neural network training algorithm',
#  'manufacturing bayesian networks ," inverse',
#  'harden prospective audio captcha schemes',
#  'big data ," query relaxation',
#  'applications ", 2014 \'), (\' 95',
#  'naive bayes classifier using four real',
#  'human biometric identification using electrocardiograms',
#  'building useful representations ," malware classification',
#  'security strength "," machine learning algorithms',
#  'cooperative caching ," content caching',
#  'artificial intelligence ), machine learning',
#  "admission experts \\' manual analysis methods",
#  'elman neural networks hold promise',
#  "monitoring patients \\' vital healthcare parameters ',",
#  'known data mining methods like clustering',
#  'efficient ssvep identification performances achieving 98',
#  'pattern mining techniques ," correlation',
#  'geophysical "," geophysical sensor technologies',
#  'brand perception measure using storylines generated',
#  'scenarios ," hybrid learning algorithms',
#  'support vector machines "," conceptual',
#  'accelerometer sensor data ," accelerometer',
#  'api "" quickly classifies images',
#  'studies proposing machine learning solutions pertaining',
#  'evoked potentials ," ballistocardiogram artifact',
#  'inductive logic programming "," delayed effects',
#  'new exact efsm inference algorithm based',
#  'sized leap motion sensor provides',
#  'arima models ," solar radiation',
#  'proposed method called manifold learning regression',
#  'artificial intelligence ), prediction algorithms',
#  "subsequent semesters becomes increasingly accurate ',",
#  'smart grid ," smart grids',
#  'mislabeled data "," software components \',',
#  "clustering big mobile social data ',",
#  "late mild cognitive impairment ',",
#  'repair ", reinforcement learning techniques become',
#  'ensemble "," spectral learning algorithms learn',
#  'proposed hybrid approach performs better fine tuning',
#  'propagation cross entropy validated neural network',
#  'feature selection based fault localization technique',
#  'algorithms may require intensive mathematical proof',
#  'social eq typically requires 25 ratings',
#  'feature selections ," keystroke dynamics',
#  "previous works usually extracted features manually ',",
#  'machine learning approaches ," spam',
#  'calibration ," car following model',
#  'prove difficult using existing search engines',
#  'genetic algorithm ," renewable energy',
#  'novel consistent variable selection algorithm based',
#  'one using correlation based feature selection',
#  'text classification ," text mining',
#  'structure learning "," bayesian network structures',
#  'temporal deep learning ," autoencoder',
#  "improve vehicular traffic flow forecasting ',",
#  'previously proposed gaussian process inferential controller',
#  'artificial defect synthetization algorithm based',
#  'railway networks ," control system',
#  'big data via multidimensional views',
#  'compatibility based intuitionistic fuzzy relation',
#  'classification method achieve 63 \\\\% accuracy',
#  'machine learning algorithms "," latencies',
#  'hierarchical classification ," hierarchical classification',
#  "generalize across different application domains ',",
#  'differentiated commodity using implicit pricing',
#  'existing retinal image quality assessment methods',
#  'robustness correlated ," neural networks',
#  'propensity score matchingtching ," accuracy',
#  'large margin cost sensitive learning objective',
#  'evolving fuzzy image segmentation -- efis',
#  'level retrieval applications used human metadata experts',
#  "minimum description length principle ',",
#  'leaf images ," machine learning',
#  'broadcast similar vehicle dynamics broadcast similar',
#  'recursive feature addition "," feature selection',
#  'unsupervised methods ," data mining',
#  'limited data ," kmeans clustering',
#  "seven biological classes previously identified ',",
#  'healthcare claims ," fraud detection',
#  'sms text "," short message service',
#  'artist identification ," classification \',',
#  'component based design petri nets',
#  'fully connected recurrent neural network',
#  'dynamic environments ," activity forecasting',
#  'complex scenarios using existing behavior models',
#  'daily total photovoltaic energy generation parameters',
#  'novel method secure data aggregation model',
#  'novel neural network based forecaster',
#  'trajectory clustering algorithm called traclus',
#  '98 \\\\% activity recognition accuracy',
#  'industrial perspective ," recommender systems',
#  'hourly solar irradiance forecasting based',
#  'paper develop artificial neural network models',
#  "machine learning system -- specifically ',",
#  'machine learning "," web scraping',
#  'mobile apps ," predicting psychosis',
#  'genetic algorithm based partitioning clustering program',
#  'intrusive human activity recognition system',
#  'semiconductor manufacturing ," machine learning',
#  'performing high dimensional nearest neighbor search',
#  "dimensional reduction follow bernoulli distribution ',",
#  'remains unclear whether existing algorithms',
#  'fusion method using canonical correlation analysis',
#  'semantic concept latent dirichlet allocation',
#  'preliminary results using existing benchmark datasets',
#  'effectively improve smartphone indoor localization compared',
#  'wireless eeg sensor nodes consume',
#  'brain signal based forensic systems',
#  'cyclic block coordinate descent method',
#  'time warping symbolic aggregation approximation',
#  'often require extensive handcrafted feature engineering',
#  'collaborative filtering "," audio equalizers',
#  'mocap )"," human action recognition',
#  'optimize car following model parameter values',
#  'effective bird syllable segmentation algorithms',
#  'optimal policies using three different multi',
#  'audio signal utilizing machine learning',
#  'orthogonal matching pursuit ","',
#  'turbulence models ," machine learning',
#  'educational institutions "," online news',
#  'dimensionality reduction ," dimensionality reduction \',',
#  'networks must model nonlinear temporal evolution',
#  "employing statistical feature ranking techniques ',",
#  'compare different neural network based linear',
#  'eeg imbalance ," transfer learning',
#  'means clustering ," indoor localization',
#  "extensive virtual world performance analysis ',",
#  'publishing automatic dbms diagnosis reports',
#  'given patient data set becomes suboptimal',
#  'bayesian hierarchical probabilistic matrix factorization',
#  'decaying potential fields neural network',
#  'gplvm ," wifi slam \',',
#  'variously shaped decision boundaries among',
#  'one obtains consistently improved performance across',
#  'cyclic contrastive divergence learning algorithm',
#  'robust nonnegative matrix factorization algorithm',
#  'stylometry "," summary sentence classification',
#  'robustly distinguish patient diagnostic categories among pre',
#  'track ," object tracking \',',
#  'using pen based tracking system',
#  'robust recurrent kernel online learning',
#  "second step using nearest neighbor ',",
#  'evolving data streams classification algorithms assume',
#  'different gene expression data holders',
#  'advanced image classification using wavelets',
#  "robust classification given noisy training instances ',",
#  'classify various car following regimes',
#  'amphiphilic chemical database ," reliability',
#  'hamming codes ," video steganography',
#  'feedforward network without sacrificing much',
#  'preliminary results ," liver segmentation',
#  'visual classification ," visual classification',
#  'content spam "," fake identities',
#  'clustering ensembles combine multiple partitions generated',
#  'posting comments enables websites visitors',
#  "cyclic contrastive divergence learning ',",
#  'found using time series similarity measures',
#  'accelerometer data "," activity recognition',
#  'detect different car following regimes',
#  'popular univariate pearson correlation coefficient',
#  "machine learning help find interesting games ',",
#  'capture local biological phenomena underlying subgroups',
#  'support vector machine learning ","',
#  'adaptive threshold "," domain adaptation methods',
#  'retrieval using support vector machines',
#  'studied using monte carlo simulations',
#  'therefore selected machine learning classification methods able',
#  'preliminary results ," kidney segmentation',
#  'computationally intensive monte carlo simulations',
#  'microalgae classification ," microalgae classification',
#  'either black boxes without explanations',
#  'inertia based activity recognition problem',
#  'supervised classification ," equations \',',
#  'machine learning techniques used biometric applications',
#  'music classification ," audio \',',
#  'valued signals ," stochastic processes',
#  'hybridising kernel principal component analysis',
#  'boosting "," ambient assisted living',
#  'political debates ," active learning',
#  'nicely mapped neural network representative',
#  'ergodic continuous hidden markov models',
#  'collected brute force netflow data',
#  'methods cannot take external forces',
#  'transcription factor binding site',
#  "support vector machines plus ',",
#  'chess game data ," machine',
#  'cnn )"," activities capture vital facts',
#  'several case studies used class decomposition combined',
#  'inferential control system entirely depend',
#  'vehicle security ," automotive security',
#  'physical systems ," vehicular cyber',
#  'bnp cluster analysis identified 5 subgroups',
#  'evaluated using audio data sets recorded',
#  'wrapper based feature subset selection approach',
#  'software projects ," software engineering',
#  'evolving graphs ," spectral clustering',
#  'music tv channels hold archives',
#  'idiopathic scoliosis patients ," scoliosis',
#  'ssh brute force attack traffic',
#  'automotive applications usage ," vehicles',
#  "switched linear dynamical systems ',",
#  'hoc analysis technique deemed useful',
#  'integrates gain parameter based backpropagation algorithm',
#  "recently developed power flow methods ',",
#  'clustering algorithms ," fault diagnosis',
#  'draws upon unsupervised machine learning',
#  'rice genome wide association studies',
#  'explore whether agents using deep q',
#  'also called "" sybils "")',
#  'multiple object tracking "," understanding activities',
#  'function -( acf ), partial',
#  'glass samples ," classification \',',
#  'kmeans -- based representation learning',
#  'learning convex piecewise linear machine',
#  'transfer learning "," fraud detection',
#  'encoders ," transfer learning \',',
#  'using four data mining techniques',
#  'multiview data "," modern data',
#  'multiview centroid based fuzzy classification',
#  'save energy without lowering comfort',
#  'financial time series ," clustering',
#  'ring finger ratio "," high rate',
#  'improvement "," computational software programs \',',
#  'electricity market ," electricity market',
#  'six well used public bayesian networks',
#  'coloured petri nets',
#  'wearable sensors "," recent trends show',
#  'testing multilayer feedforward neural networks',
#  "subject independent universal gmm model ',",
#  'experiment using software defect data',
#  "expected solar plant power output ',",
#  'proposed algorithm includes four different stages',
#  'artificial intelligence ), computer science',
#  'external independent cohorts ," rule',
#  'deep learning "," patent classification',
#  'based clustering ," fault diagnosis',
#  'partitioning problems ," bayes methods',
#  'based personalized audio equalization system',
#  'car following markov regime classification',
#  "study include ibm model 1 ',",
#  'dc converters ," neural network',
#  'neurological disorders requires extensive research',
#  'network topology "," partially connected ann',
#  'automatic topic labeling using ontology',
#  'deep learning "," object recognition',
#  "determine whether aggregated esm data ',",
#  'hence automatic spam detection techniques play',
#  'neural network based kidney segmentation',
#  'twitter streams ," twitter \',',
#  'daily total global solar radiation',
#  'fault detection using machine learning',
#  "matching high quality slide images ',",
#  'email service providers may mark',
#  'liver segmentation using probabilistic atlases',
#  'web robots ," web robots',
#  'machine learning systems entails tools',
#  'model first calculates similarity scores based',
#  'method using molecular networks alone',
#  'classification ," coordinate descent',
#  'mapping f .", statistical learning',
#  'adaptation ," brain computer interface',
#  'hierarchical clustering ," class decomposition',
#  'negative distance kernel ," svm',
#  'function -( pacf ), granger',
#  'processing association rules using networks',
#  'snacks "," chronic conditions \',',
#  'chinese event coreference resolution datasets',
#  'common musical events using pitch',
#  "high fluctuating data rates ',",
#  'bayesian nonparametric inverse reinforcement learning',
#  'cell classification using microscope images',
#  'indira sagar canal command area',
#  'indira sagar canal command area',
#  'brand new video distribution platform youtube',
#  'pulmonary density analysis feature extractor',
#  'stack overflow ," churn prediction',
#  'supervised "," aligning video sequences',
#  'recent developed ensemble feature selection methods',
#  'different classification techniques using weka',
#  "convolutional neural network variant ',",
#  'confidence region "," general predictive models',
#  'kohonen self organizing neural networks',
#  'graph representation "," activity recognition',
#  'semantic concept hierarchical dirichlet process',
#  'conditional linear gaussian bayesian networks',
#  'gaussian process inferential control system',
#  'videos using action bank features',
#  'traffic exhibits decidedly different statistical',
#  'experts model whose regression coefficients evolve',
#  'present empirical experiments using data gathered',
#  "namely 3d shape class recognition ',",
#  'length exact motif discovery algorithm',
#  'day ahead solar irradiance forecasting',
#  'wind power plant ," meta',
#  'rtrl ), kernel online learning',
#  'paper uses convolutional neural networks',
#  'model using machine learning techniques',
#  'use sticky hierarchical dirichlet process',
#  'establish new cyber forensics methods ",',
#  'adaptive learning "," automatic detection',
#  'prove several fuzzy soft operations based',
#  "early mild cognitive impairment ',",
#  'next generation wheel alignment systems',
#  'masked conditional neural networks',
#  "tangent bundle manifold learning ',",
#  'american sign language using',
#  'transfer learning "," anomaly detection',
#  'partially connected anns ," optimization',
#  "biological differences within subpopulations ',",
#  'mining big mobile social data',
#  'enable accurate classification within complex domains',
#  'extend conventional stationary spectral analysis approaches',
#  'seizure detection outside clinical settings',
#  'field programmable gate array technology',
#  'operational data ," predictive models',
#  "use four different data sets ',",
#  'symbolized time series string based',
#  'numerical simulation "," bayesian nonparametric',
#  "generate four representative paths ',",
#  "three popular consensus integration algorithms ',",
#  'auxiliary objectives using reinforcement learning',
#  'propose mean field variational inference algorithms',
#  'objective reinforcement learning ," multi',
#  'es ," mass transfer \',',
#  'uci sms spam collection data set',
#  '"" domain class imbalance "".',
#  'smart meter "," accurate network',
#  'resampling "," building radiation hybrid',
#  'probabilistic random forest ," ecg',
#  "plate orientation towards brightness ',",
#  'gatk based parallel commutating scheme',
#  'learn decision boundaries directly without taking',
#  'sourced virtual world simulator opensimulator',
#  'mrmr "," maximising electricity production',
#  "known phonetic matching technique ',",
#  'data privacy ," data privacy',
#  'climate "," causal discovery algorithms',
#  'unsupervised learning "," every organism',
#  'strong expression power causing overfitting',
#  'ritm give considerably good results individually',
#  'critical arrhythmia alarms ," electrocardiography',
#  'time anomaly detection algorithms –',
#  'support vector regression based methods',
#  'using natural language descriptions improves',
#  'support vector machine based classifiers',
#  "one network service becomes unavailable ',",
#  'neurofuzzy system "," image processing',
#  "grained regimes like braking ',",
#  'medical provider fraud investigation cases',
#  'event based weight update learning',
#  'applicants ," partitioning clustering \',',
#  ...]

# %%
data = r.get_ranked_phrases_with_scores()

# %%
print(data)
# Out:
# [(75.69835234245883, 'arctic sea ice extent forecasting using support vector regression ," arctic sea ice \','), (74.9156608822785, 'lecture vdeo indexing using boosted margin maximizing neural networks ," video indexing'), (67.04380371475769, 'extensive empirical study utilizing four bootstrap approaches within bagging framework using three feature rankers along'), (64.7465503754522, 'next generation wireless networks using coloured petri nets ," next generation wireless networks'), (63.02983379234418, 'topic novelty detection using infinite variational inverted dirichlet mixture models ," inverted dirichlet'), (59.70844466683605, 'sunspot number using minimum error entropy cost based kernel adaptive filters ," kernel methods'), (58.91860832056751, 'shot periodic activity recognition using convolutional neural networks ," human activity recognition \','), (55.08300912106397, 'uncertainty quantified matrix completion using bayesian hierarchical matrix factorization ," bayesian analysis \','), (54.815499557952975, 'based inferential control system using kernel principle component analysis ," control systems \','), (53.60932000217184, 'audio signal reconstruction using cartesian genetic programming evolved artificial neural network'), (53.55139104650917, 'linear estimation algorithm called cartesian genetic programming evolved artificial neural network'), (53.47313732460905, 'direct multiclass boosting using base classifiers \\\' posterior probabilities estimates ," machine learning'), (52.807404681473855, 'action bank features using convolutional neural networks ," human action recognition \','), (51.547936062916044, 'intensive care units via orthogonal matching pursuit ," logistic regression \','), (50.57378390508989, 'relationships found reveal semantic paths linking two concepts across multiple text units'), (50.05136238030975, 'scene matching "," optical images display drastically reduced visibility due'), (49.95658492592781, 'acoustic events using masked conditional neural networks ," restricted boltzmann machine'), (49.926356990032964, 'ssh brute force attacks using aggregated netflow data ," intrusion detection'), (49.30029478088299, 'smart grid using cgp evolved artificial neural networks ," cgpann'), (48.9138768443565, 'residential house using artificial neural networks ," artificial neural network'), (48.525754685229884, 'variable neural network forecasting using two stage feature selection ," forecasting \','), (47.78734715675066, 'forward looking sonar scene matching using deep learning ," deep learning'), (47.4916710456536, 'infrared colorization using deep convolutional neural networks ," neural networks'), (47.1858309105565, 'mocap information using convolution neural networks ," convolutional neural networks'), (47.146790679418174, 'major classical face recognition techniques ," blind source seperation \','), (47.008132444288364, 'automatically refining manually built bayesian networks ," medical informatics \','), (46.75534527756635, 'applications workshop ", 2015 \'), (\' 186 ," measuring level'), (46.71788643573828, 'neuro evolutionary cartesian genetic programming evolved artificial neural network'), (46.51373314719637, 'detecting credit card fraud using periodic features ," fraud detection'), (46.39592025368484, 'intelligent bus stop identification using smartphone sensors ," intelligent systems'), (46.335397555780595, 'second model called "" exponentially weighted ensemble "" combines individual regressors'), (45.959786404457596, 'lifelong machine learning systems ," lifelong machine learning \','), (45.721888382014846, 'computed tomography via optimum path snakes ," active contour method'), (45.707431331530586, 'machine learning based cyber forensic biometric systems ," cyber forensic'), (45.60739159029286, '2017 \'), (\' 409 ," cybersecurity automated information extraction techniques'), (45.38455515786199, 'thin film flow problem using stochastic solver like genetic algorithm'), (45.156594818877295, 'po ...

# %%
df = pd.DataFrame (data, columns = ['score', 'phrase'])
print (df)
# Out:
#            score                                             phrase
# 0      75.698352  arctic sea ice extent forecasting using suppor...
# 1      74.915661  lecture vdeo indexing using boosted margin max...
# 2      67.043804  extensive empirical study utilizing four boots...
# 3      64.746550  next generation wireless networks using colour...
# 4      63.029834  topic novelty detection using infinite variati...
# ...          ...                                                ...
# 28618   1.000000                                                 *.
# 28619   1.000000                                                "',
# 28620   1.000000                                                "',
# 28621   1.000000                                                "',
# 28622   1.000000                                                "',
#
# [28623 rows x 2 columns]

# %%
r.preprocess(corpus)
r.extract_keywords_from_text(corpus)
r.get_ranked_phrases()
# Out:
# ['known manner comprises two kinds',
#  'keeping machine intended',
#  'new balances resulting',
#  'new balances',
#  'old balances',
#  'subtracting wheels',
#  'invention relates',
#  'counting wheels',
#  'balance mechanism',
#  'amounts received',
#  'viz',
#  'serves',
#  'recording',
#  'paid',
#  'calculation',
#  'calculation',
#  'book',
#  'adding',
#  'account']

# %%
data = r.get_ranked_phrases_with_scores()

# %%
print(data)
# Out:
# [(25.0, 'known manner comprises two kinds'), (9.0, 'keeping machine intended'), (7.833333333333334, 'new balances resulting'), (4.833333333333334, 'new balances'), (4.333333333333334, 'old balances'), (4.0, 'subtracting wheels'), (4.0, 'invention relates'), (4.0, 'counting wheels'), (4.0, 'balance mechanism'), (4.0, 'amounts received'), (1.0, 'viz'), (1.0, 'serves'), (1.0, 'recording'), (1.0, 'paid'), (1.0, 'calculation'), (1.0, 'calculation'), (1.0, 'book'), (1.0, 'adding'), (1.0, 'account')]

# %%
df = pd.DataFrame (data, columns = ['score', 'phrase'])
print (df)
# Out:
#         score                            phrase
# 0   25.000000  known manner comprises two kinds
# 1    9.000000          keeping machine intended
# 2    7.833333            new balances resulting
# 3    4.833333                      new balances
# 4    4.333333                      old balances
# 5    4.000000                subtracting wheels
# 6    4.000000                 invention relates
# 7    4.000000                   counting wheels
# 8    4.000000                 balance mechanism
# 9    4.000000                  amounts received
# 10   1.000000                               viz
# 11   1.000000                            serves
# 12   1.000000                         recording
# 13   1.000000                              paid
# 14   1.000000                       calculation
# 15   1.000000                       calculation
# 16   1.000000                              book
# 17   1.000000                            adding
# 18   1.000000                           account

# %%
df.to_csv('rake.csv', index = False)

# %%
from __future__ import absolute_import
from __future__ import print_function
from six.moves import range
import sys

# %%
rake_object = stopwords.words('english')

# %%
type(rake_object)
# Out:
# list

# %%
top = len(data)

test_score = df['score'] 
test_name= df['phrase'] 

total_precision = 0
total_recall = 0

# %%
    correct = 0
    num_manual_keywords = len(rake_object)
    for i in range(0, len(data)):
        if data[i][0] in set(df['score']):
            correct += 1
            total_precision += correct/float(len(data))
            total_recall += correct/float(len(rake_object))
    print('correct:', correct, 'out of', num_manual_keywords)
# Out:
# correct: 28623 out of 179

# %%
avg_precision = round(total_precision*100/float(len(data)), 2)
avg_recall = round(total_recall/float(len(data)), 2)

avg_fmeasure = round(2*avg_precision*avg_recall/(avg_precision + avg_recall), 2)
avg_accuracy = round((total_precision + total_recall)/(float(len(data))*2),2)

print("Precision", avg_precision, "Recall", avg_recall, "F-Measure", avg_fmeasure, "Accuracy", avg_accuracy)
# Out:
# Precision 50.0 Recall 79.96 F-Measure 61.53 Accuracy 40.23
